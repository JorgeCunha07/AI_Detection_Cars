# %%
import json
import os
import random
import time

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from PIL import Image, ImageDraw, ImageFont
from torch.cuda.amp import GradScaler
from torch.utils.data import DataLoader, Subset
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights, resnet50, vgg16
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.ops import MultiScaleRoIAlign

from dataset_class import MultiTaskObjectDetectionDataset, collate_fn

# %%
###########################################
# 2. Funções de Geração de Modelos
###########################################
def create_mobilenet_model(num_classes):
    mobilenet = mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V2)
    backbone = mobilenet.features
    backbone.out_channels = 1280
    anchor_gen = AnchorGenerator(sizes=((32, 64, 128, 256, 512),),
                                 aspect_ratios=((0.5, 1.0, 2.0),))
    roi_pool = MultiScaleRoIAlign(featmap_names=["0"], output_size=7, sampling_ratio=2)
    model = FasterRCNN(backbone, num_classes=num_classes, rpn_anchor_generator=anchor_gen, box_roi_pool=roi_pool)
    return model, backbone, 1280


def create_resnet_model(num_classes):
    backbone = resnet50(pretrained=True)
    modules = list(backbone.children())[:-2]
    backbone = nn.Sequential(*modules)
    backbone.out_channels = 2048
    anchor_gen = AnchorGenerator(sizes=((32, 64, 128, 256, 512),),
                                 aspect_ratios=((0.5, 1.0, 2.0),))
    roi_pool = MultiScaleRoIAlign(featmap_names=["0"], output_size=7, sampling_ratio=2)
    model = FasterRCNN(backbone, num_classes=num_classes, rpn_anchor_generator=anchor_gen, box_roi_pool=roi_pool)
    return model, backbone, 2048


def create_vgg_model(num_classes):
    backbone = vgg16(pretrained=True).features
    backbone.out_channels = 512
    anchor_gen = AnchorGenerator(sizes=((32, 64, 128, 256, 512),),
                                 aspect_ratios=((0.5, 1.0, 2.0),))
    roi_pool = MultiScaleRoIAlign(featmap_names=["0"], output_size=7, sampling_ratio=2)
    model = FasterRCNN(backbone, num_classes=num_classes, rpn_anchor_generator=anchor_gen, box_roi_pool=roi_pool)
    return model, backbone, 512


def create_yolo_model(num_classes):
    class SimpleYOLO(nn.Module):
        def __init__(self, num_classes):
            super(SimpleYOLO, self).__init__()
            self.features = nn.Sequential(
                nn.Conv2d(3, 32, kernel_size=3, padding=1),
                nn.BatchNorm2d(32),
                nn.ReLU(),
                nn.MaxPool2d(2),  # Reduz pela metade
                nn.Conv2d(32, 64, kernel_size=3, padding=1),
                nn.BatchNorm2d(64),
                nn.ReLU(),
                nn.MaxPool2d(2),  # Reduz pela metade
                nn.AdaptiveAvgPool2d((7, 7))  # Garantir saída fixa 7x7
            )

            self.classifier = nn.Sequential(
                nn.Flatten(),
                nn.Linear(64 * 7 * 7, 256),
                nn.ReLU(),
                nn.Linear(256, num_classes)
            )

            self.box_regressor = nn.Sequential(
                nn.Flatten(),
                nn.Linear(64 * 7 * 7, 256),
                nn.ReLU(),
                nn.Linear(256, 4)
            )

        def forward(self, images, targets=None):
            features = [self.features(img.unsqueeze(0)) for img in images]
            logits = torch.cat([self.classifier(feat) for feat in features], dim=0)
            boxes = torch.cat([self.box_regressor(feat) for feat in features], dim=0)

            if targets is None:
                pred_labels = logits.argmax(dim=1)
                pred_scores = torch.softmax(logits, dim=1).max(dim=1).values
                return [{"boxes": boxes, "labels": pred_labels, "scores": pred_scores}]

            labels = torch.cat([t["labels"] for t in targets], dim=0)
            gt_boxes = torch.cat([t["boxes"] for t in targets], dim=0)

            cls_loss = nn.functional.cross_entropy(logits, labels)
            box_loss = nn.functional.l1_loss(boxes, gt_boxes)

            losses = {
                "classification_loss": cls_loss,
                "bbox_regression_loss": box_loss
            }

            return losses

    model = SimpleYOLO(num_classes)
    return model, None, None


class ScratchDetector(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Linear(64, num_classes)
        self.box_regressor = nn.Linear(64, 4)

    def forward(self, images, targets=None):
        x = torch.stack(images)  # [B, C, H, W]
        feats = self.features(x)  # [B, 64, H, W]
        pooled = self.avgpool(feats)  # [B, 64, 1, 1]
        pooled = pooled.view(pooled.size(0), -1)  # [B, 64]
        class_logits = self.classifier(pooled)
        box_preds = self.box_regressor(pooled)

        if targets is not None:
            labels = torch.cat([t["labels"] for t in targets], dim=0)
            gt_boxes = torch.cat([t["boxes"] for t in targets], dim=0)
            repeats = torch.tensor([len(t["labels"]) for t in targets], device=class_logits.device)
            loss_cls = F.cross_entropy(class_logits.repeat_interleave(repeats, dim=0), labels)
            loss_box = F.l1_loss(box_preds.repeat_interleave(repeats, dim=0), gt_boxes)
            return {"classification_loss": loss_cls, "bbox_regression_loss": loss_box}
        else:
            return [{
                "labels": torch.argmax(class_logits[i]).unsqueeze(0),
                "boxes": box_preds[i].unsqueeze(0)
            } for i in range(len(images))]


def create_scratch_model(num_classes):
    model = ScratchDetector(num_classes)
    return model, None, None

# %%
###########################################
# 3. Classe MultiTaskModel (Detecção + Atributos Globais)
###########################################
class MultiTaskModel(nn.Module):
    def __init__(self, detection_model, backbone, num_weather, num_scene, num_time, in_features):
        super(MultiTaskModel, self).__init__()
        self.detection_model = detection_model
        self.backbone = backbone
        self.attr_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc_weather = nn.Linear(in_features, num_weather)
        self.fc_scene = nn.Linear(in_features, num_scene)
        self.fc_timeofday = nn.Linear(in_features, num_time)

    def forward(self, images, targets=None, global_attrs=None):
        # Em treinamento, retorna losses; em avaliação, retorna as detecções
        if self.training:
            detection_loss = self.detection_model(images, targets)
        else:
            detection_loss = self.detection_model(images)
        imgs_tensor = torch.stack(images)
        feats = self.backbone(imgs_tensor)
        pooled = self.attr_pool(feats)
        pooled = pooled.view(pooled.size(0), -1)
        weather_logits = self.fc_weather(pooled)
        scene_logits = self.fc_scene(pooled)
        timeofday_logits = self.fc_timeofday(pooled)
        if self.training and global_attrs is not None:
            weather_labels = torch.stack([attr["weather"] for attr in global_attrs]).to(images[0].device)
            scene_labels = torch.stack([attr["scene"] for attr in global_attrs]).to(images[0].device)
            timeofday_labels = torch.stack([attr["timeofday"] for attr in global_attrs]).to(images[0].device)
            loss_weather = nn.functional.cross_entropy(weather_logits, weather_labels)
            loss_scene = nn.functional.cross_entropy(scene_logits, scene_labels)
            loss_timeofday = nn.functional.cross_entropy(timeofday_logits, timeofday_labels)
            attr_loss = loss_weather + loss_scene + loss_timeofday
        else:
            attr_loss = 0
        return detection_loss, attr_loss, weather_logits, scene_logits, timeofday_logits

# %%
###########################################
# 4. Pipeline de Treinamento, Avaliação e Inferência
###########################################
# Configurações iniciais
transform = transforms.Compose([transforms.ToTensor()])
splits = {
    "train": ("images/train", "labels/train"),
    "val": ("images/val", "labels/val"),
    "test": ("images/test", "labels/test")
}
datasets, loaders = {}, {}
for split, (img_dir, lbl_dir) in splits.items():
    print(f"📂 Carregando dataset '{split}'...")
    ds = MultiTaskObjectDetectionDataset(img_dir, lbl_dir, transform)
    subset_size = max(1, int(len(ds) * 0.50))  # Usa 50% dos dados
    indices = random.sample(range(len(ds)), subset_size)
    ds_subset = Subset(ds, indices)
    datasets[split] = ds_subset
    loaders[split] = DataLoader(
        ds_subset, batch_size=8, shuffle=(split == "train"),
        collate_fn=collate_fn, num_workers=0)
    print(f"Utilizando {subset_size} de {len(ds)} imagens para o split '{split}' (50%).")

# Carrega os mapeamentos
with open("helpers/categories.json", "r") as f:
    category_to_label = json.load(f)
with open("helpers/weather.json", "r") as f:
    weather_to_label = json.load(f)
with open("helpers/scene.json", "r") as f:
    scene_to_label = json.load(f)
with open("helpers/timeofday.json", "r") as f:
    timeofday_to_label = json.load(f)

num_classes = len(category_to_label) + 1
num_weather = len(weather_to_label)
num_scene = len(scene_to_label)
num_time = len(timeofday_to_label)

# Define o dispositivo (GPU se disponível)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🖥️ Usando dispositivo: {device}")

# Escolha do modelo: "mobilenet", "resnet", "vgg", "yolo", "scratch"
model_type = "scratch"  # Altere conforme necessário
if model_type == "mobilenet":
    detection_model, backbone, in_features = create_mobilenet_model(num_classes)
elif model_type == "resnet":
    detection_model, backbone, in_features = create_resnet_model(num_classes)
elif model_type == "vgg":
    detection_model, backbone, in_features = create_vgg_model(num_classes)
elif model_type == "yolo":
    detection_model, backbone, in_features = create_yolo_model(num_classes)
elif model_type == "scratch":
    detection_model, backbone, in_features = create_scratch_model(num_classes)
else:
    raise ValueError("Modelo inválido.")

if backbone is None or in_features is None:
    multi_task_model = detection_model
else:
    # Congelar camadas iniciais
    for param in backbone.parameters():
        param.requires_grad = False
    multi_task_model = MultiTaskModel(detection_model, backbone, num_weather, num_scene, num_time, in_features=in_features)
multi_task_model = multi_task_model.to(device)

# Otimizador e AMP
optimizer = torch.optim.AdamW(filter(lambda p: p.requires_grad, multi_task_model.parameters()), lr=1e-4)
scaler = GradScaler()

# Treinamento com Early Stopping (máximo 50 épocas ou sem melhora significativa nas últimas 5 épocas)
max_epochs = 50
early_stop_patience = 5
min_delta = 1e-3
best_loss = float("inf")
no_improve_epochs = 0
loss_history = []

print(f"Modelo tem {sum(p.numel() for p in multi_task_model.parameters())} parâmetros.")
print(f"Número de workers: {loaders['train'].num_workers}")
print(f"Pin memory: {loaders['train'].pin_memory}")
print(f"Batch size: {loaders['train'].batch_size}")
print(f"Dispositivo: {device}")

print("🚀 Iniciando treinamento...")
for epoch in range(max_epochs):
    multi_task_model.train()
    epoch_loss = 0
    epoch_start = time.time()
    total_batches = len(loaders["train"])
    print(f"\n🌀 Epoch {epoch + 1}/{max_epochs} - Total Batches: {total_batches}")

    for batch_idx, (images, targets, attrs) in enumerate(loaders["train"], start=1):
        print(f"🧱 Processando batch {batch_idx + 1}/{total_batches}")
        batch_start = time.time()
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        optimizer.zero_grad()
        if model_type in ["mobilenet", "resnet", "vgg"]:
            with torch.cuda.amp.autocast():
                det_loss, attr_loss, *_ = multi_task_model(images, targets, attrs)
                loss = sum(det_loss.values()) + attr_loss
        elif model_type in ["yolo", "scratch"]:
            # modelos YOLO e Scratch não têm atributos adicionais,
            det_loss = multi_task_model(images, targets)
            loss = sum(det_loss.values())
        else:
            raise ValueError("Modelo não reconhecido.")

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        batch_time = time.time() - batch_start
        remaining_batches = total_batches - batch_idx
        estimated_remaining_time = remaining_batches * batch_time
        print(
            f"📦 Epoch {epoch + 1}, Batch {batch_idx}/{total_batches} | Loss: {loss.item():.4f} | Time: {batch_time:.2f}s | ⏳ Est. time left: {estimated_remaining_time:.1f}s")

        epoch_loss += loss.item()

    avg_epoch_loss = epoch_loss / total_batches
    epoch_duration = time.time() - epoch_start
    print(f"\n✅ Epoch {epoch + 1} complete. Avg Loss: {avg_epoch_loss:.4f}, Duration: {epoch_duration:.2f}s")

    # Criar pasta para logs, se não existir
    os.makedirs("logs", exist_ok=True)
    log_path = f"logs/training_log_{model_type}.json"

    # Calcular progresso e ETA
    progress = (epoch + 1) / max_epochs
    estimated_total_time = epoch_duration / progress
    estimated_remaining_time = estimated_total_time - (epoch + 1) * epoch_duration / (epoch + 1)

    # Atualiza histórico
    loss_history.append({
        "epoch": epoch + 1,
        "avg_loss": avg_epoch_loss,
        "duration_sec": epoch_duration,
        "best_loss_so_far": best_loss,
        "no_improve_epochs": no_improve_epochs,
        "estimated_remaining_time_sec": round(estimated_remaining_time, 1)
    })

    # Salvar como JSON
    with open(log_path, "w") as f:
        json.dump(loss_history, f, indent=4)
    print(f"📄 Log de treino salvo em {log_path}")

    if best_loss - avg_epoch_loss > min_delta:
        best_loss = avg_epoch_loss
        no_improve_epochs = 0
        torch.save(multi_task_model, f"multi_task_model_{model_type}.pth")  # Melhor modelo
        print(f"💾 Novo melhor modelo salvo como 'multi_task_model_{model_type}.pth'")
    else:
        no_improve_epochs += 1
        if no_improve_epochs >= early_stop_patience:
            print("🛑 Early stopping triggered.")
            break
# Out:
# 📂 Carregando dataset 'train'...
# Todas as imagens possuem JSON correspondente.
# Utilizando 3500 de 7000 imagens para o split 'train' (50%).
# 📂 Carregando dataset 'val'...
# Todas as imagens possuem JSON correspondente.
# Utilizando 500 de 1000 imagens para o split 'val' (50%).
# 📂 Carregando dataset 'test'...
# Todas as imagens possuem JSON correspondente.
# Utilizando 1000 de 2000 imagens para o split 'test' (50%).
# 🖥️ Usando dispositivo: cuda
# Modelo tem 20692 parâmetros.
# Número de workers: 0
# Pin memory: False
# Batch size: 8
# Dispositivo: cuda
# 🚀 Iniciando treinamento...
#
# 🌀 Epoch 1/50 - Total Batches: 438
# C:\Users\ctw02813\AppData\Local\Temp\ipykernel_22768\1184826009.py:69: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# 🧱 Processando batch 2/438
# 📦 Epoch 1, Batch 1/438 | Loss: 509.2242 | Time: 3.11s | ⏳ Est. time left: 1358.8s
# 🧱 Processando batch 3/438
# 📦 Epoch 1, Batch 2/438 | Loss: 516.7505 | Time: 1.98s | ⏳ Est. time left: 865.1s
# 🧱 Processando batch 4/438
# 📦 Epoch 1, Batch 3/438 | Loss: 509.2208 | Time: 1.96s | ⏳ Est. time left: 850.9s
# 🧱 Processando batch 5/438
# 📦 Epoch 1, Batch 4/438 | Loss: 506.6373 | Time: 1.95s | ⏳ Est. time left: 846.3s
# 🧱 Processando batch 6/438
# 📦 Epoch 1, Batch 5/438 | Loss: 541.9933 | Time: 1.92s | ⏳ Est. time left: 829.8s
# 🧱 Processando batch 7/438
# 📦 Epoch 1, Batch 6/438 | Loss: 449.0386 | Time: 1.92s | ⏳ Est. time left: 827.7s
# 🧱 Processando batch 8/438
# 📦 Epoch 1, Batch 7/438 | Loss: 508.0652 | Time: 1.91s | ⏳ Est. time left: 823.4s
# 🧱 Processando batch 9/438
# 📦 Epoch 1, Batch 8/438 | Loss: 504.3287 | Time: 1.91s | ⏳ Est. time left: 823.0s
# 🧱 Processando batch 10/438
# 📦 Epoch 1, Batch 9/438 | Loss: 456.1363 | Time: 1.91s | ⏳ Est. time left: 818.5s
# 🧱 Processando batch 11/438
# 📦 Epoch 1, Batch 10/438 | Loss: 482.0568 | Time: 1.90s | ⏳ Est. time left: 815.1s
# 🧱 Processando batch 12/438
# 📦 Epoch 1, Batch 11/438 | Loss: 483.4440 | Time: 1.91s | ⏳ Est. time left: 814.8s
# 🧱 Processando batch 13/438
# 📦 Epoch 1, Batch 12/438 | Loss: 540.7841 | Time: 1.91s | ⏳ Est. time left: 812.3s
# 🧱 Processando batch 14/438
# 📦 Epoch 1, Batch 13/438 | Loss: 502.8867 | Time: 1.91s | ⏳ Est. time left: 812.4s
# 🧱 Processando batch 15/438
# 📦 Epoch 1, Batch 14/438 | Loss: 550.2921 | Time: 1.91s | ⏳ Est. time left: 809.3s
# 🧱 Processando batch 16/438
# 📦 Epoch 1, Batch 15/438 | Loss: 478.5230 | Time: 1.93s | ⏳ Est. time left: 817.2s
# 🧱 Processando batch 17/438
# 📦 Epoch 1, Batch 16/438 | Loss: 488.5799 | Time: 1.95s | ⏳ Est. time left: 824.3s
# 🧱 Processando batch 18/438
# 📦 Epoch 1, Batch 17/438 | Loss: 509.2425 | Time: 1.95s | ⏳ Est. time left: 823.0s
# 🧱 Processando batch 19/438
# 📦 Epoch 1, Batch 18/438 | Loss: 531.2591 | Time: 1.99s | ⏳ Est. time left: 837.5s
# 🧱 Processando batch 20/438
# 📦 Epoch 1, Batch 19/438 | Loss: 507.6786 | Time: 1.95s | ⏳ Est. time left: 817.8s
# 🧱 Processando batch 21/438
# 📦 Epoch 1, Batch 20/438 | Loss: 530.7174 | Time: 1.96s | ⏳ Est. time left: 818.0s
# 🧱 Processando batch 22/438
# 📦 Epoch 1, Batch 21/438 | Loss: 528.0702 | Time: 1.99s | ⏳ Est. time left: 830.9s
# 🧱 Processando batch 23/438
# 📦 Epoch 1, Batch 22/438 | Loss: 502.2697 | Time: 1.97s | ⏳ Est. time left: 820.9s
# 🧱 Processando batch 24/438
# 📦 Epoch 1, Batch 23/438 | Loss: 477.4783 | Time: 2.01s | ⏳ Est. time left: 834.7s
# 🧱 Processando batch 25/438
# 📦 Epoch 1, Batch 24/438 | Loss: 508.9020 | Time: 2.22s | ⏳ Est. time left: 919.9s
# 🧱 Processando batch 26/438
# 📦 Epoch 1, Batch 25/438 | Loss: 498.1080 | Time: 2.12s | ⏳ Est. time left: 875.8s
# 🧱 Processando batch 27/438
# 📦 Epoch 1, Batch 26/438 | Loss: 518.0312 | Time: 2.07s | ⏳ Est. time left: 853.1s
# 🧱 Processando batch 28/438
# 📦 Epoch 1, Batch 27/438 | Loss: 482.2072 | Time: 2.06s | ⏳ Est. time left: 846.8s
# 🧱 Processando batch 29/438
# 📦 Epoch 1, Batch 28/438 | Loss: 540.4256 | Time: 2.06s | ⏳ Est. time left: 844.2s
# 🧱 Processando batch 30/438
# 📦 Epoch 1, Batch 29/438 | Loss: 528.4611 | Time: 2.05s | ⏳ Est. time left: 838.5s
# 🧱 Processando batch 31/438
# 📦 Epoch 1, Batch 30/438 | Loss: 508.0252 | Time: 2.05s | ⏳ Est. time left: 836.5s
# 🧱 Processando batch 32/438
# 📦 Epoch 1, Batch 31/438 | Loss: 518.4598 | Time: 2.06s | ⏳ Est. time left: 840.4s
# 🧱 Processando batch 33/438
# 📦 Epoch 1, Batch 32/438 | Loss: 511.9849 | Time: 2.05s | ⏳ Est. time left: 833.3s
# 🧱 Processando batch 34/438
# 📦 Epoch 1, Batch 33/438 | Loss: 539.7239 | Time: 2.06s | ⏳ Est. time left: 833.5s
# 🧱 Processando batch 35/438
# 📦 Epoch 1, Batch 34/438 | Loss: 536.2460 | Time: 2.05s | ⏳ Est. time left: 826.4s
# 🧱 Processando batch 36/438
# 📦 Epoch 1, Batch 35/438 | Loss: 531.8353 | Time: 2.06s | ⏳ Est. time left: 831.7s
# 🧱 Processando batch 37/438
# 📦 Epoch 1, Batch 36/438 | Loss: 527.2633 | Time: 2.07s | ⏳ Est. time left: 831.4s
# 🧱 Processando batch 38/438
# 📦 Epoch 1, Batch 37/438 | Loss: 471.9409 | Time: 2.05s | ⏳ Est. time left: 823.3s
# 🧱 Processando batch 39/438
# 📦 Epoch 1, Batch 38/438 | Loss: 542.4944 | Time: 2.08s | ⏳ Est. time left: 830.3s
# 🧱 Processando batch 40/438
# 📦 Epoch 1, Batch 39/438 | Loss: 505.7071 | Time: 2.07s | ⏳ Est. time left: 827.7s
# 🧱 Processando batch 41/438
# 📦 Epoch 1, Batch 40/438 | Loss: 498.8191 | Time: 2.08s | ⏳ Est. time left: 826.3s
# 🧱 Processando batch 42/438
# 📦 Epoch 1, Batch 41/438 | Loss: 505.4516 | Time: 2.06s | ⏳ Est. time left: 818.3s
# 🧱 Processando batch 43/438
# 📦 Epoch 1, Batch 42/438 | Loss: 549.4130 | Time: 2.07s | ⏳ Est. time left: 818.1s
# 🧱 Processando batch 44/438
# 📦 Epoch 1, Batch 43/438 | Loss: 493.0803 | Time: 2.06s | ⏳ Est. time left: 812.3s
# 🧱 Processando batch 45/438
# 📦 Epoch 1, Batch 44/438 | Loss: 473.1236 | Time: 2.06s | ⏳ Est. time left: 811.8s
# 🧱 Processando batch 46/438
# 📦 Epoch 1, Batch 45/438 | Loss: 490.3687 | Time: 2.05s | ⏳ Est. time left: 806.3s
# 🧱 Processando batch 47/438
# 📦 Epoch 1, Batch 46/438 | Loss: 491.8488 | Time: 2.06s | ⏳ Est. time left: 806.8s
# 🧱 Processando batch 48/438
# 📦 Epoch 1, Batch 47/438 | Loss: 508.1543 | Time: 2.06s | ⏳ Est. time left: 803.8s
# 🧱 Processando batch 49/438
# 📦 Epoch 1, Batch 48/438 | Loss: 480.2774 | Time: 2.04s | ⏳ Est. time left: 796.4s
# 🧱 Processando batch 50/438
# 📦 Epoch 1, Batch 49/438 | Loss: 496.3180 | Time: 2.06s | ⏳ Est. time left: 801.6s
# 🧱 Processando batch 51/438
# 📦 Epoch 1, Batch 50/438 | Loss: 522.4444 | Time: 2.05s | ⏳ Est. time left: 796.1s
# 🧱 Processando batch 52/438
# 📦 Epoch 1, Batch 51/438 | Loss: 482.9702 | Time: 2.06s | ⏳ Est. time left: 796.8s
# 🧱 Processando batch 53/438
# 📦 Epoch 1, Batch 52/438 | Loss: 503.2619 | Time: 2.06s | ⏳ Est. time left: 794.8s
# 🧱 Processando batch 54/438
# 📦 Epoch 1, Batch 53/438 | Loss: 499.4090 | Time: 1.77s | ⏳ Est. time left: 681.9s
# 🧱 Processando batch 55/438
# 📦 Epoch 1, Batch 54/438 | Loss: 497.9460 | Time: 2.06s | ⏳ Est. time left: 790.6s
# 🧱 Processando batch 56/438
# 📦 Epoch 1, Batch 55/438 | Loss: 495.4901 | Time: 2.06s | ⏳ Est. time left: 789.5s
# 🧱 Processando batch 57/438
# 📦 Epoch 1, Batch 56/438 | Loss: 501.6358 | Time: 2.06s | ⏳ Est. time left: 785.1s
# 🧱 Processando batch 58/438
# 📦 Epoch 1, Batch 57/438 | Loss: 512.6958 | Time: 2.06s | ⏳ Est. time left: 784.1s
# 🧱 Processando batch 59/438
# 📦 Epoch 1, Batch 58/438 | Loss: 481.4634 | Time: 2.06s | ⏳ Est. time left: 781.1s
# 🧱 Processando batch 60/438
# 📦 Epoch 1, Batch 59/438 | Loss: 516.7928 | Time: 1.78s | ⏳ Est. time left: 674.3s
# 🧱 Processando batch 61/438
# 📦 Epoch 1, Batch 60/438 | Loss: 560.4843 | Time: 2.06s | ⏳ Est. time left: 777.8s
# 🧱 Processando batch 62/438
# 📦 Epoch 1, Batch 61/438 | Loss: 563.4231 | Time: 2.07s | ⏳ Est. time left: 780.2s
# 🧱 Processando batch 63/438
# 📦 Epoch 1, Batch 62/438 | Loss: 493.4232 | Time: 2.06s | ⏳ Est. time left: 775.7s
# 🧱 Processando batch 64/438
# 📦 Epoch 1, Batch 63/438 | Loss: 550.0102 | Time: 2.09s | ⏳ Est. time left: 782.5s
# 🧱 Processando batch 65/438
# 📦 Epoch 1, Batch 64/438 | Loss: 462.5916 | Time: 1.94s | ⏳ Est. time left: 724.0s
# 🧱 Processando batch 66/438
# 📦 Epoch 1, Batch 65/438 | Loss: 502.6722 | Time: 1.93s | ⏳ Est. time left: 719.1s
# 🧱 Processando batch 67/438
# 📦 Epoch 1, Batch 66/438 | Loss: 494.6673 | Time: 1.94s | ⏳ Est. time left: 720.2s
# 🧱 Processando batch 68/438
# 📦 Epoch 1, Batch 67/438 | Loss: 504.3934 | Time: 1.98s | ⏳ Est. time left: 734.0s
# 🧱 Processando batch 69/438
# 📦 Epoch 1, Batch 68/438 | Loss: 508.3298 | Time: 2.07s | ⏳ Est. time left: 764.8s
# 🧱 Processando batch 70/438
# 📦 Epoch 1, Batch 69/438 | Loss: 500.5265 | Time: 2.12s | ⏳ Est. time left: 780.6s
# 🧱 Processando batch 71/438
# 📦 Epoch 1, Batch 70/438 | Loss: 530.3034 | Time: 1.94s | ⏳ Est. time left: 715.4s
# 🧱 Processando batch 72/438
# 📦 Epoch 1, Batch 71/438 | Loss: 494.5056 | Time: 2.06s | ⏳ Est. time left: 757.3s
# 🧱 Processando batch 73/438
# 📦 Epoch 1, Batch 72/438 | Loss: 535.2857 | Time: 2.12s | ⏳ Est. time left: 775.3s
# 🧱 Processando batch 74/438
# 📦 Epoch 1, Batch 73/438 | Loss: 488.6024 | Time: 1.96s | ⏳ Est. time left: 713.8s
# 🧱 Processando batch 75/438
# 📦 Epoch 1, Batch 74/438 | Loss: 506.2054 | Time: 1.95s | ⏳ Est. time left: 709.2s
# 🧱 Processando batch 76/438
# 📦 Epoch 1, Batch 75/438 | Loss: 498.0805 | Time: 1.95s | ⏳ Est. time left: 708.9s
# 🧱 Processando batch 77/438
# 📦 Epoch 1, Batch 76/438 | Loss: 518.1423 | Time: 1.94s | ⏳ Est. time left: 701.4s
# 🧱 Processando batch 78/438
# 📦 Epoch 1, Batch 77/438 | Loss: 460.9509 | Time: 1.92s | ⏳ Est. time left: 694.5s
# 🧱 Processando batch 79/438
# 📦 Epoch 1, Batch 78/438 | Loss: 435.9258 | Time: 1.93s | ⏳ Est. time left: 693.7s
# 🧱 Processando batch 80/438
# 📦 Epoch 1, Batch 79/438 | Loss: 487.6743 | Time: 1.95s | ⏳ Est. time left: 698.7s
# 🧱 Processando batch 81/438
# 📦 Epoch 1, Batch 80/438 | Loss: 504.7368 | Time: 1.95s | ⏳ Est. time left: 699.2s
# 🧱 Processando batch 82/438
# 📦 Epoch 1, Batch 81/438 | Loss: 567.2851 | Time: 2.10s | ⏳ Est. time left: 749.4s
# 🧱 Processando batch 83/438
# 📦 Epoch 1, Batch 82/438 | Loss: 549.0399 | Time: 2.06s | ⏳ Est. time left: 731.6s
# 🧱 Processando batch 84/438
# 📦 Epoch 1, Batch 83/438 | Loss: 412.9106 | Time: 2.06s | ⏳ Est. time left: 732.5s
# 🧱 Processando batch 85/438
# 📦 Epoch 1, Batch 84/438 | Loss: 525.5657 | Time: 2.09s | ⏳ Est. time left: 740.5s
# 🧱 Processando batch 86/438
# 📦 Epoch 1, Batch 85/438 | Loss: 463.5252 | Time: 2.08s | ⏳ Est. time left: 733.4s
# 🧱 Processando batch 87/438
# 📦 Epoch 1, Batch 86/438 | Loss: 509.9705 | Time: 2.06s | ⏳ Est. time left: 725.2s
# 🧱 Processando batch 88/438
# 📦 Epoch 1, Batch 87/438 | Loss: 468.5000 | Time: 2.02s | ⏳ Est. time left: 710.0s
# 🧱 Processando batch 89/438
# 📦 Epoch 1, Batch 88/438 | Loss: 506.8844 | Time: 2.10s | ⏳ Est. time left: 735.4s
# 🧱 Processando batch 90/438
# 📦 Epoch 1, Batch 89/438 | Loss: 537.9419 | Time: 2.07s | ⏳ Est. time left: 724.0s
# 🧱 Processando batch 91/438
# 📦 Epoch 1, Batch 90/438 | Loss: 532.3608 | Time: 2.06s | ⏳ Est. time left: 718.2s
# 🧱 Processando batch 92/438
# 📦 Epoch 1, Batch 91/438 | Loss: 488.0197 | Time: 2.06s | ⏳ Est. time left: 715.5s
# 🧱 Processando batch 93/438
# 📦 Epoch 1, Batch 92/438 | Loss: 546.0033 | Time: 2.16s | ⏳ Est. time left: 747.7s
# 🧱 Processando batch 94/438
# 📦 Epoch 1, Batch 93/438 | Loss: 511.2823 | Time: 2.19s | ⏳ Est. time left: 757.2s
# 🧱 Processando batch 95/438
# 📦 Epoch 1, Batch 94/438 | Loss: 558.8009 | Time: 2.07s | ⏳ Est. time left: 712.7s
# 🧱 Processando batch 96/438
# 📦 Epoch 1, Batch 95/438 | Loss: 498.7695 | Time: 2.05s | ⏳ Est. time left: 702.3s
# 🧱 Processando batch 97/438
# 📦 Epoch 1, Batch 96/438 | Loss: 489.5114 | Time: 2.17s | ⏳ Est. time left: 743.2s
# 🧱 Processando batch 98/438
# 📦 Epoch 1, Batch 97/438 | Loss: 491.8907 | Time: 2.16s | ⏳ Est. time left: 736.3s
# 🧱 Processando batch 99/438
# 📦 Epoch 1, Batch 98/438 | Loss: 532.6193 | Time: 2.18s | ⏳ Est. time left: 740.8s
# 🧱 Processando batch 100/438
# 📦 Epoch 1, Batch 99/438 | Loss: 517.9448 | Time: 1.75s | ⏳ Est. time left: 592.9s
# 🧱 Processando batch 101/438
# 📦 Epoch 1, Batch 100/438 | Loss: 449.7472 | Time: 1.98s | ⏳ Est. time left: 667.6s
# 🧱 Processando batch 102/438
# 📦 Epoch 1, Batch 101/438 | Loss: 501.7253 | Time: 1.79s | ⏳ Est. time left: 603.9s
# 🧱 Processando batch 103/438
# 📦 Epoch 1, Batch 102/438 | Loss: 535.8914 | Time: 2.14s | ⏳ Est. time left: 718.2s
# 🧱 Processando batch 104/438
# 📦 Epoch 1, Batch 103/438 | Loss: 515.6036 | Time: 1.86s | ⏳ Est. time left: 621.7s
# 🧱 Processando batch 105/438
# 📦 Epoch 1, Batch 104/438 | Loss: 574.1472 | Time: 2.12s | ⏳ Est. time left: 707.1s
# 🧱 Processando batch 106/438
# 📦 Epoch 1, Batch 105/438 | Loss: 472.1306 | Time: 1.82s | ⏳ Est. time left: 607.6s
# 🧱 Processando batch 107/438
# 📦 Epoch 1, Batch 106/438 | Loss: 541.2206 | Time: 2.09s | ⏳ Est. time left: 692.6s
# 🧱 Processando batch 108/438
# 📦 Epoch 1, Batch 107/438 | Loss: 449.4138 | Time: 2.09s | ⏳ Est. time left: 691.0s
# 🧱 Processando batch 109/438
# 📦 Epoch 1, Batch 108/438 | Loss: 562.8549 | Time: 2.10s | ⏳ Est. time left: 693.6s
# 🧱 Processando batch 110/438
# 📦 Epoch 1, Batch 109/438 | Loss: 489.3019 | Time: 2.12s | ⏳ Est. time left: 697.9s
# 🧱 Processando batch 111/438
# 📦 Epoch 1, Batch 110/438 | Loss: 505.8468 | Time: 2.02s | ⏳ Est. time left: 662.4s
# 🧱 Processando batch 112/438
# 📦 Epoch 1, Batch 111/438 | Loss: 519.4531 | Time: 2.08s | ⏳ Est. time left: 679.4s
# 🧱 Processando batch 113/438
# 📦 Epoch 1, Batch 112/438 | Loss: 550.8568 | Time: 1.98s | ⏳ Est. time left: 644.7s
# 🧱 Processando batch 114/438
# 📦 Epoch 1, Batch 113/438 | Loss: 486.7404 | Time: 1.93s | ⏳ Est. time left: 626.7s
# 🧱 Processando batch 115/438
# 📦 Epoch 1, Batch 114/438 | Loss: 489.0537 | Time: 1.96s | ⏳ Est. time left: 633.6s
# 🧱 Processando batch 116/438
# 📦 Epoch 1, Batch 115/438 | Loss: 569.5674 | Time: 1.96s | ⏳ Est. time left: 634.6s
# 🧱 Processando batch 117/438
# 📦 Epoch 1, Batch 116/438 | Loss: 485.9688 | Time: 1.96s | ⏳ Est. time left: 630.2s
# 🧱 Processando batch 118/438
# 📦 Epoch 1, Batch 117/438 | Loss: 530.4751 | Time: 1.95s | ⏳ Est. time left: 626.1s
# 🧱 Processando batch 119/438
# 📦 Epoch 1, Batch 118/438 | Loss: 541.7343 | Time: 1.91s | ⏳ Est. time left: 612.6s
# 🧱 Processando batch 120/438
# 📦 Epoch 1, Batch 119/438 | Loss: 536.4379 | Time: 2.09s | ⏳ Est. time left: 666.8s
# 🧱 Processando batch 121/438
# 📦 Epoch 1, Batch 120/438 | Loss: 513.2332 | Time: 1.94s | ⏳ Est. time left: 615.6s
# 🧱 Processando batch 122/438
# 📦 Epoch 1, Batch 121/438 | Loss: 468.8317 | Time: 1.91s | ⏳ Est. time left: 604.2s
# 🧱 Processando batch 123/438
# 📦 Epoch 1, Batch 122/438 | Loss: 449.6202 | Time: 1.94s | ⏳ Est. time left: 612.2s
# 🧱 Processando batch 124/438
# 📦 Epoch 1, Batch 123/438 | Loss: 522.5110 | Time: 1.94s | ⏳ Est. time left: 611.9s
# 🧱 Processando batch 125/438
# 📦 Epoch 1, Batch 124/438 | Loss: 513.0728 | Time: 1.92s | ⏳ Est. time left: 601.5s
# 🧱 Processando batch 126/438
# 📦 Epoch 1, Batch 125/438 | Loss: 507.1448 | Time: 2.10s | ⏳ Est. time left: 657.2s
# 🧱 Processando batch 127/438
# 📦 Epoch 1, Batch 126/438 | Loss: 526.3820 | Time: 1.74s | ⏳ Est. time left: 544.2s
# 🧱 Processando batch 128/438
# 📦 Epoch 1, Batch 127/438 | Loss: 463.9125 | Time: 1.92s | ⏳ Est. time left: 596.1s
# 🧱 Processando batch 129/438
# 📦 Epoch 1, Batch 128/438 | Loss: 511.5815 | Time: 1.92s | ⏳ Est. time left: 595.6s
# 🧱 Processando batch 130/438
# 📦 Epoch 1, Batch 129/438 | Loss: 503.7028 | Time: 1.94s | ⏳ Est. time left: 599.0s
# 🧱 Processando batch 131/438
# 📦 Epoch 1, Batch 130/438 | Loss: 524.7907 | Time: 1.93s | ⏳ Est. time left: 595.1s
# 🧱 Processando batch 132/438
# 📦 Epoch 1, Batch 131/438 | Loss: 450.2624 | Time: 1.97s | ⏳ Est. time left: 603.7s
# 🧱 Processando batch 133/438
# 📦 Epoch 1, Batch 132/438 | Loss: 506.0332 | Time: 2.01s | ⏳ Est. time left: 616.0s
# 🧱 Processando batch 134/438
# 📦 Epoch 1, Batch 133/438 | Loss: 505.3704 | Time: 1.93s | ⏳ Est. time left: 587.4s
# 🧱 Processando batch 135/438
# 📦 Epoch 1, Batch 134/438 | Loss: 469.9491 | Time: 1.92s | ⏳ Est. time left: 584.9s
# 🧱 Processando batch 136/438
# 📦 Epoch 1, Batch 135/438 | Loss: 465.9669 | Time: 2.06s | ⏳ Est. time left: 625.2s
# 🧱 Processando batch 137/438
# 📦 Epoch 1, Batch 136/438 | Loss: 513.3017 | Time: 1.93s | ⏳ Est. time left: 583.2s
# 🧱 Processando batch 138/438
# 📦 Epoch 1, Batch 137/438 | Loss: 501.9224 | Time: 1.94s | ⏳ Est. time left: 583.8s
# 🧱 Processando batch 139/438
# 📦 Epoch 1, Batch 138/438 | Loss: 440.5558 | Time: 2.02s | ⏳ Est. time left: 605.0s
# 🧱 Processando batch 140/438
# 📦 Epoch 1, Batch 139/438 | Loss: 464.4182 | Time: 2.08s | ⏳ Est. time left: 621.8s
# 🧱 Processando batch 141/438
# 📦 Epoch 1, Batch 140/438 | Loss: 512.7046 | Time: 2.07s | ⏳ Est. time left: 617.5s
# 🧱 Processando batch 142/438
# 📦 Epoch 1, Batch 141/438 | Loss: 553.4464 | Time: 2.24s | ⏳ Est. time left: 665.0s
# 🧱 Processando batch 143/438
# 📦 Epoch 1, Batch 142/438 | Loss: 528.6857 | Time: 2.08s | ⏳ Est. time left: 615.5s
# 🧱 Processando batch 144/438
# 📦 Epoch 1, Batch 143/438 | Loss: 551.6057 | Time: 2.12s | ⏳ Est. time left: 624.4s
# 🧱 Processando batch 145/438
# 📦 Epoch 1, Batch 144/438 | Loss: 476.8408 | Time: 2.16s | ⏳ Est. time left: 634.6s
# 🧱 Processando batch 146/438
# 📦 Epoch 1, Batch 145/438 | Loss: 455.0048 | Time: 2.19s | ⏳ Est. time left: 640.8s
# 🧱 Processando batch 147/438
# 📦 Epoch 1, Batch 146/438 | Loss: 483.0505 | Time: 2.24s | ⏳ Est. time left: 653.2s
# 🧱 Processando batch 148/438
# 📦 Epoch 1, Batch 147/438 | Loss: 491.8255 | Time: 2.12s | ⏳ Est. time left: 615.7s
# 🧱 Processando batch 149/438
# 📦 Epoch 1, Batch 148/438 | Loss: 497.2856 | Time: 2.05s | ⏳ Est. time left: 595.3s
# 🧱 Processando batch 150/438
# 📦 Epoch 1, Batch 149/438 | Loss: 559.0644 | Time: 2.06s | ⏳ Est. time left: 594.9s
# 🧱 Processando batch 151/438
# 📦 Epoch 1, Batch 150/438 | Loss: 493.3231 | Time: 2.07s | ⏳ Est. time left: 595.1s
# 🧱 Processando batch 152/438
# 📦 Epoch 1, Batch 151/438 | Loss: 538.6428 | Time: 2.25s | ⏳ Est. time left: 645.8s
# 🧱 Processando batch 153/438
# 📦 Epoch 1, Batch 152/438 | Loss: 481.0702 | Time: 2.19s | ⏳ Est. time left: 627.6s
# 🧱 Processando batch 154/438
# 📦 Epoch 1, Batch 153/438 | Loss: 541.5002 | Time: 2.16s | ⏳ Est. time left: 616.0s
# 🧱 Processando batch 155/438
# 📦 Epoch 1, Batch 154/438 | Loss: 513.8868 | Time: 2.11s | ⏳ Est. time left: 600.5s
# 🧱 Processando batch 156/438
# 📦 Epoch 1, Batch 155/438 | Loss: 534.7914 | Time: 2.10s | ⏳ Est. time left: 593.2s
# 🧱 Processando batch 157/438
# 📦 Epoch 1, Batch 156/438 | Loss: 560.6125 | Time: 2.21s | ⏳ Est. time left: 622.6s
# 🧱 Processando batch 158/438
# 📦 Epoch 1, Batch 157/438 | Loss: 520.4261 | Time: 2.04s | ⏳ Est. time left: 572.4s
# 🧱 Processando batch 159/438
# 📦 Epoch 1, Batch 158/438 | Loss: 517.1894 | Time: 2.05s | ⏳ Est. time left: 574.5s
# 🧱 Processando batch 160/438
# 📦 Epoch 1, Batch 159/438 | Loss: 496.0365 | Time: 2.04s | ⏳ Est. time left: 569.6s
# 🧱 Processando batch 161/438
# 📦 Epoch 1, Batch 160/438 | Loss: 504.0381 | Time: 2.07s | ⏳ Est. time left: 576.1s
# 🧱 Processando batch 162/438
# 📦 Epoch 1, Batch 161/438 | Loss: 512.8769 | Time: 2.14s | ⏳ Est. time left: 594.0s
# 🧱 Processando batch 163/438
# 📦 Epoch 1, Batch 162/438 | Loss: 495.5092 | Time: 2.08s | ⏳ Est. time left: 574.6s
# 🧱 Processando batch 164/438
# 📦 Epoch 1, Batch 163/438 | Loss: 545.3670 | Time: 2.08s | ⏳ Est. time left: 572.3s
# 🧱 Processando batch 165/438
# 📦 Epoch 1, Batch 164/438 | Loss: 466.8948 | Time: 1.96s | ⏳ Est. time left: 536.5s
# 🧱 Processando batch 166/438
# 📦 Epoch 1, Batch 165/438 | Loss: 538.6941 | Time: 1.95s | ⏳ Est. time left: 532.7s
# 🧱 Processando batch 167/438
# 📦 Epoch 1, Batch 166/438 | Loss: 525.6761 | Time: 2.16s | ⏳ Est. time left: 587.5s
# 🧱 Processando batch 168/438
# 📦 Epoch 1, Batch 167/438 | Loss: 460.4089 | Time: 2.09s | ⏳ Est. time left: 566.3s
# 🧱 Processando batch 169/438
# 📦 Epoch 1, Batch 168/438 | Loss: 516.0753 | Time: 1.98s | ⏳ Est. time left: 535.3s
# 🧱 Processando batch 170/438
# 📦 Epoch 1, Batch 169/438 | Loss: 550.4828 | Time: 1.94s | ⏳ Est. time left: 522.9s
# 🧱 Processando batch 171/438
# 📦 Epoch 1, Batch 170/438 | Loss: 518.7673 | Time: 1.95s | ⏳ Est. time left: 523.3s
# 🧱 Processando batch 172/438
# 📦 Epoch 1, Batch 171/438 | Loss: 529.6084 | Time: 1.94s | ⏳ Est. time left: 517.5s
# 🧱 Processando batch 173/438
# 📦 Epoch 1, Batch 172/438 | Loss: 475.9269 | Time: 2.10s | ⏳ Est. time left: 558.2s
# 🧱 Processando batch 174/438
# 📦 Epoch 1, Batch 173/438 | Loss: 519.4317 | Time: 2.17s | ⏳ Est. time left: 574.5s
# 🧱 Processando batch 175/438
# 📦 Epoch 1, Batch 174/438 | Loss: 515.2755 | Time: 2.16s | ⏳ Est. time left: 570.8s
# 🧱 Processando batch 176/438
# 📦 Epoch 1, Batch 175/438 | Loss: 507.6977 | Time: 2.12s | ⏳ Est. time left: 558.3s
# 🧱 Processando batch 177/438
# 📦 Epoch 1, Batch 176/438 | Loss: 513.2422 | Time: 2.14s | ⏳ Est. time left: 559.7s
# 🧱 Processando batch 178/438
# 📦 Epoch 1, Batch 177/438 | Loss: 479.1166 | Time: 2.04s | ⏳ Est. time left: 532.1s
# 🧱 Processando batch 179/438
# 📦 Epoch 1, Batch 178/438 | Loss: 477.6046 | Time: 2.05s | ⏳ Est. time left: 532.1s
# 🧱 Processando batch 180/438
# 📦 Epoch 1, Batch 179/438 | Loss: 529.8903 | Time: 2.04s | ⏳ Est. time left: 529.3s
# 🧱 Processando batch 181/438
# 📦 Epoch 1, Batch 180/438 | Loss: 490.9454 | Time: 2.05s | ⏳ Est. time left: 529.2s
# 🧱 Processando batch 182/438
# 📦 Epoch 1, Batch 181/438 | Loss: 476.4762 | Time: 2.04s | ⏳ Est. time left: 525.5s
# 🧱 Processando batch 183/438
# 📦 Epoch 1, Batch 182/438 | Loss: 465.9889 | Time: 2.14s | ⏳ Est. time left: 548.6s
# 🧱 Processando batch 184/438
# 📦 Epoch 1, Batch 183/438 | Loss: 531.1340 | Time: 2.19s | ⏳ Est. time left: 557.2s
# 🧱 Processando batch 185/438
# 📦 Epoch 1, Batch 184/438 | Loss: 491.5948 | Time: 2.18s | ⏳ Est. time left: 554.9s
# 🧱 Processando batch 186/438
# 📦 Epoch 1, Batch 185/438 | Loss: 552.7397 | Time: 2.18s | ⏳ Est. time left: 550.3s
# 🧱 Processando batch 187/438
# 📦 Epoch 1, Batch 186/438 | Loss: 504.6319 | Time: 2.12s | ⏳ Est. time left: 535.3s
# 🧱 Processando batch 188/438
# 📦 Epoch 1, Batch 187/438 | Loss: 491.5917 | Time: 2.11s | ⏳ Est. time left: 529.1s
# 🧱 Processando batch 189/438
# 📦 Epoch 1, Batch 188/438 | Loss: 520.1617 | Time: 2.06s | ⏳ Est. time left: 514.9s
# 🧱 Processando batch 190/438
# 📦 Epoch 1, Batch 189/438 | Loss: 511.7467 | Time: 2.05s | ⏳ Est. time left: 510.4s
# 🧱 Processando batch 191/438
# 📦 Epoch 1, Batch 190/438 | Loss: 522.2071 | Time: 2.06s | ⏳ Est. time left: 510.7s
# 🧱 Processando batch 192/438
# 📦 Epoch 1, Batch 191/438 | Loss: 475.0341 | Time: 2.06s | ⏳ Est. time left: 508.2s
# 🧱 Processando batch 193/438
# 📦 Epoch 1, Batch 192/438 | Loss: 511.8132 | Time: 2.05s | ⏳ Est. time left: 504.1s
# 🧱 Processando batch 194/438
# 📦 Epoch 1, Batch 193/438 | Loss: 490.7621 | Time: 2.06s | ⏳ Est. time left: 503.9s
# 🧱 Processando batch 195/438
# 📦 Epoch 1, Batch 194/438 | Loss: 560.4147 | Time: 2.05s | ⏳ Est. time left: 501.2s
# 🧱 Processando batch 196/438
# 📦 Epoch 1, Batch 195/438 | Loss: 472.9191 | Time: 2.06s | ⏳ Est. time left: 501.1s
# 🧱 Processando batch 197/438
# 📦 Epoch 1, Batch 196/438 | Loss: 538.8669 | Time: 2.05s | ⏳ Est. time left: 497.0s
# 🧱 Processando batch 198/438
# 📦 Epoch 1, Batch 197/438 | Loss: 499.4047 | Time: 2.06s | ⏳ Est. time left: 496.4s
# 🧱 Processando batch 199/438
# 📦 Epoch 1, Batch 198/438 | Loss: 510.3010 | Time: 2.06s | ⏳ Est. time left: 494.9s
# 🧱 Processando batch 200/438
# 📦 Epoch 1, Batch 199/438 | Loss: 476.9951 | Time: 1.77s | ⏳ Est. time left: 423.8s
# 🧱 Processando batch 201/438
# 📦 Epoch 1, Batch 200/438 | Loss: 476.3870 | Time: 2.06s | ⏳ Est. time left: 491.3s
# 🧱 Processando batch 202/438
# 📦 Epoch 1, Batch 201/438 | Loss: 496.0334 | Time: 2.05s | ⏳ Est. time left: 486.4s
# 🧱 Processando batch 203/438
# 📦 Epoch 1, Batch 202/438 | Loss: 438.1577 | Time: 2.06s | ⏳ Est. time left: 486.3s
# 🧱 Processando batch 204/438
# 📦 Epoch 1, Batch 203/438 | Loss: 496.8172 | Time: 2.08s | ⏳ Est. time left: 489.0s
# 🧱 Processando batch 205/438
# 📦 Epoch 1, Batch 204/438 | Loss: 485.6737 | Time: 2.08s | ⏳ Est. time left: 486.2s
# 🧱 Processando batch 206/438
# 📦 Epoch 1, Batch 205/438 | Loss: 508.5941 | Time: 2.08s | ⏳ Est. time left: 484.3s
# 🧱 Processando batch 207/438
# 📦 Epoch 1, Batch 206/438 | Loss: 496.2445 | Time: 2.05s | ⏳ Est. time left: 475.0s
# 🧱 Processando batch 208/438
# 📦 Epoch 1, Batch 207/438 | Loss: 526.6971 | Time: 2.06s | ⏳ Est. time left: 475.0s
# 🧱 Processando batch 209/438
# 📦 Epoch 1, Batch 208/438 | Loss: 443.1228 | Time: 2.07s | ⏳ Est. time left: 475.5s
# 🧱 Processando batch 210/438
# 📦 Epoch 1, Batch 209/438 | Loss: 474.7160 | Time: 2.09s | ⏳ Est. time left: 478.6s
# 🧱 Processando batch 211/438
# 📦 Epoch 1, Batch 210/438 | Loss: 510.6733 | Time: 2.10s | ⏳ Est. time left: 478.0s
# 🧱 Processando batch 212/438
# 📦 Epoch 1, Batch 211/438 | Loss: 516.0531 | Time: 2.07s | ⏳ Est. time left: 470.6s
# 🧱 Processando batch 213/438
# 📦 Epoch 1, Batch 212/438 | Loss: 442.3767 | Time: 2.11s | ⏳ Est. time left: 477.0s
# 🧱 Processando batch 214/438
# 📦 Epoch 1, Batch 213/438 | Loss: 443.6266 | Time: 2.12s | ⏳ Est. time left: 475.9s
# 🧱 Processando batch 215/438
# 📦 Epoch 1, Batch 214/438 | Loss: 507.3066 | Time: 2.12s | ⏳ Est. time left: 475.8s
# 🧱 Processando batch 216/438
# 📦 Epoch 1, Batch 215/438 | Loss: 487.7678 | Time: 2.09s | ⏳ Est. time left: 466.7s
# 🧱 Processando batch 217/438
# 📦 Epoch 1, Batch 216/438 | Loss: 551.2590 | Time: 2.09s | ⏳ Est. time left: 464.6s
# 🧱 Processando batch 218/438
# 📦 Epoch 1, Batch 217/438 | Loss: 485.6216 | Time: 2.09s | ⏳ Est. time left: 462.1s
# 🧱 Processando batch 219/438
# 📦 Epoch 1, Batch 218/438 | Loss: 510.1860 | Time: 2.10s | ⏳ Est. time left: 462.8s
# 🧱 Processando batch 220/438
# 📦 Epoch 1, Batch 219/438 | Loss: 473.3114 | Time: 2.15s | ⏳ Est. time left: 470.3s
# 🧱 Processando batch 221/438
# 📦 Epoch 1, Batch 220/438 | Loss: 487.8259 | Time: 2.07s | ⏳ Est. time left: 451.5s
# 🧱 Processando batch 222/438
# 📦 Epoch 1, Batch 221/438 | Loss: 454.6494 | Time: 2.14s | ⏳ Est. time left: 463.3s
# 🧱 Processando batch 223/438
# 📦 Epoch 1, Batch 222/438 | Loss: 521.1929 | Time: 2.13s | ⏳ Est. time left: 461.0s
# 🧱 Processando batch 224/438
# 📦 Epoch 1, Batch 223/438 | Loss: 504.4255 | Time: 2.10s | ⏳ Est. time left: 451.5s
# 🧱 Processando batch 225/438
# 📦 Epoch 1, Batch 224/438 | Loss: 416.7216 | Time: 2.10s | ⏳ Est. time left: 449.6s
# 🧱 Processando batch 226/438
# 📦 Epoch 1, Batch 225/438 | Loss: 508.3556 | Time: 2.07s | ⏳ Est. time left: 441.2s
# 🧱 Processando batch 227/438
# 📦 Epoch 1, Batch 226/438 | Loss: 493.6172 | Time: 2.07s | ⏳ Est. time left: 438.6s
# 🧱 Processando batch 228/438
# 📦 Epoch 1, Batch 227/438 | Loss: 507.2710 | Time: 2.06s | ⏳ Est. time left: 434.8s
# 🧱 Processando batch 229/438
# 📦 Epoch 1, Batch 228/438 | Loss: 585.7562 | Time: 2.09s | ⏳ Est. time left: 438.5s
# 🧱 Processando batch 230/438
# 📦 Epoch 1, Batch 229/438 | Loss: 488.8290 | Time: 2.06s | ⏳ Est. time left: 429.7s
# 🧱 Processando batch 231/438
# 📦 Epoch 1, Batch 230/438 | Loss: 500.1656 | Time: 2.06s | ⏳ Est. time left: 429.4s
# 🧱 Processando batch 232/438
# 📦 Epoch 1, Batch 231/438 | Loss: 467.8306 | Time: 2.08s | ⏳ Est. time left: 429.8s
# 🧱 Processando batch 233/438
# 📦 Epoch 1, Batch 232/438 | Loss: 422.8980 | Time: 2.08s | ⏳ Est. time left: 428.2s
# 🧱 Processando batch 234/438
# 📦 Epoch 1, Batch 233/438 | Loss: 452.1472 | Time: 2.08s | ⏳ Est. time left: 426.5s
# 🧱 Processando batch 235/438
# 📦 Epoch 1, Batch 234/438 | Loss: 517.6355 | Time: 2.09s | ⏳ Est. time left: 427.0s
# 🧱 Processando batch 236/438
# 📦 Epoch 1, Batch 235/438 | Loss: 484.0550 | Time: 2.06s | ⏳ Est. time left: 419.1s
# 🧱 Processando batch 237/438
# 📦 Epoch 1, Batch 236/438 | Loss: 593.0424 | Time: 2.11s | ⏳ Est. time left: 425.2s
# 🧱 Processando batch 238/438
# 📦 Epoch 1, Batch 237/438 | Loss: 472.8050 | Time: 2.08s | ⏳ Est. time left: 417.7s
# 🧱 Processando batch 239/438
# 📦 Epoch 1, Batch 238/438 | Loss: 449.7442 | Time: 2.08s | ⏳ Est. time left: 415.9s
# 🧱 Processando batch 240/438
# 📦 Epoch 1, Batch 239/438 | Loss: 472.6565 | Time: 2.07s | ⏳ Est. time left: 411.0s
# 🧱 Processando batch 241/438
# 📦 Epoch 1, Batch 240/438 | Loss: 520.8292 | Time: 2.06s | ⏳ Est. time left: 408.5s
# 🧱 Processando batch 242/438
# 📦 Epoch 1, Batch 241/438 | Loss: 522.5614 | Time: 2.07s | ⏳ Est. time left: 408.0s
# 🧱 Processando batch 243/438
# 📦 Epoch 1, Batch 242/438 | Loss: 485.7256 | Time: 2.06s | ⏳ Est. time left: 403.3s
# 🧱 Processando batch 244/438
# 📦 Epoch 1, Batch 243/438 | Loss: 495.4922 | Time: 2.05s | ⏳ Est. time left: 399.1s
# 🧱 Processando batch 245/438
# 📦 Epoch 1, Batch 244/438 | Loss: 512.4498 | Time: 2.05s | ⏳ Est. time left: 397.2s
# 🧱 Processando batch 246/438
# 📦 Epoch 1, Batch 245/438 | Loss: 505.5357 | Time: 2.04s | ⏳ Est. time left: 393.7s
# 🧱 Processando batch 247/438
# 📦 Epoch 1, Batch 246/438 | Loss: 467.6564 | Time: 2.04s | ⏳ Est. time left: 392.4s
# 🧱 Processando batch 248/438
# 📦 Epoch 1, Batch 247/438 | Loss: 535.1035 | Time: 2.06s | ⏳ Est. time left: 393.4s
# 🧱 Processando batch 249/438
# 📦 Epoch 1, Batch 248/438 | Loss: 501.8368 | Time: 2.07s | ⏳ Est. time left: 392.7s
# 🧱 Processando batch 250/438
# 📦 Epoch 1, Batch 249/438 | Loss: 518.1790 | Time: 2.05s | ⏳ Est. time left: 388.0s
# 🧱 Processando batch 251/438
# 📦 Epoch 1, Batch 250/438 | Loss: 490.5588 | Time: 2.05s | ⏳ Est. time left: 385.7s
# 🧱 Processando batch 252/438
# 📦 Epoch 1, Batch 251/438 | Loss: 448.7616 | Time: 2.05s | ⏳ Est. time left: 382.9s
# 🧱 Processando batch 253/438
# 📦 Epoch 1, Batch 252/438 | Loss: 504.4286 | Time: 2.06s | ⏳ Est. time left: 383.4s
# 🧱 Processando batch 254/438
# 📦 Epoch 1, Batch 253/438 | Loss: 526.6563 | Time: 2.05s | ⏳ Est. time left: 378.4s
# 🧱 Processando batch 255/438
# 📦 Epoch 1, Batch 254/438 | Loss: 471.8280 | Time: 2.04s | ⏳ Est. time left: 376.0s
# 🧱 Processando batch 256/438
# 📦 Epoch 1, Batch 255/438 | Loss: 502.7770 | Time: 2.04s | ⏳ Est. time left: 374.2s
# 🧱 Processando batch 257/438
# 📦 Epoch 1, Batch 256/438 | Loss: 497.9756 | Time: 2.04s | ⏳ Est. time left: 371.7s
# 🧱 Processando batch 258/438
# 📦 Epoch 1, Batch 257/438 | Loss: 504.2760 | Time: 2.05s | ⏳ Est. time left: 371.3s
# 🧱 Processando batch 259/438
# 📦 Epoch 1, Batch 258/438 | Loss: 492.8175 | Time: 2.07s | ⏳ Est. time left: 373.5s
# 🧱 Processando batch 260/438
# 📦 Epoch 1, Batch 259/438 | Loss: 477.8265 | Time: 2.04s | ⏳ Est. time left: 365.2s
# 🧱 Processando batch 261/438
# 📦 Epoch 1, Batch 260/438 | Loss: 493.9225 | Time: 2.04s | ⏳ Est. time left: 363.5s
# 🧱 Processando batch 262/438
# 📦 Epoch 1, Batch 261/438 | Loss: 517.4096 | Time: 2.06s | ⏳ Est. time left: 363.8s
# 🧱 Processando batch 263/438
# 📦 Epoch 1, Batch 262/438 | Loss: 502.7451 | Time: 2.05s | ⏳ Est. time left: 360.8s
# 🧱 Processando batch 264/438
# 📦 Epoch 1, Batch 263/438 | Loss: 503.3677 | Time: 2.07s | ⏳ Est. time left: 361.6s
# 🧱 Processando batch 265/438
# 📦 Epoch 1, Batch 264/438 | Loss: 539.1673 | Time: 2.10s | ⏳ Est. time left: 365.0s
# 🧱 Processando batch 266/438
# 📦 Epoch 1, Batch 265/438 | Loss: 524.0427 | Time: 2.09s | ⏳ Est. time left: 360.9s
# 🧱 Processando batch 267/438
# 📦 Epoch 1, Batch 266/438 | Loss: 497.1599 | Time: 2.05s | ⏳ Est. time left: 352.7s
# 🧱 Processando batch 268/438
# 📦 Epoch 1, Batch 267/438 | Loss: 460.2864 | Time: 2.05s | ⏳ Est. time left: 351.1s
# 🧱 Processando batch 269/438
# 📦 Epoch 1, Batch 268/438 | Loss: 461.6028 | Time: 2.04s | ⏳ Est. time left: 347.5s
# 🧱 Processando batch 270/438
# 📦 Epoch 1, Batch 269/438 | Loss: 488.6890 | Time: 2.07s | ⏳ Est. time left: 350.2s
# 🧱 Processando batch 271/438
# 📦 Epoch 1, Batch 270/438 | Loss: 457.3066 | Time: 2.10s | ⏳ Est. time left: 352.4s
# 🧱 Processando batch 272/438
# 📦 Epoch 1, Batch 271/438 | Loss: 430.7875 | Time: 2.09s | ⏳ Est. time left: 348.6s
# 🧱 Processando batch 273/438
# 📦 Epoch 1, Batch 272/438 | Loss: 472.5909 | Time: 2.07s | ⏳ Est. time left: 344.0s
# 🧱 Processando batch 274/438
# 📦 Epoch 1, Batch 273/438 | Loss: 509.2213 | Time: 2.05s | ⏳ Est. time left: 338.7s
# 🧱 Processando batch 275/438
# 📦 Epoch 1, Batch 274/438 | Loss: 478.8542 | Time: 2.07s | ⏳ Est. time left: 339.7s
# 🧱 Processando batch 276/438
# 📦 Epoch 1, Batch 275/438 | Loss: 487.5117 | Time: 2.08s | ⏳ Est. time left: 338.7s
# 🧱 Processando batch 277/438
# 📦 Epoch 1, Batch 276/438 | Loss: 464.9427 | Time: 2.08s | ⏳ Est. time left: 337.0s
# 🧱 Processando batch 278/438
# 📦 Epoch 1, Batch 277/438 | Loss: 518.3601 | Time: 2.08s | ⏳ Est. time left: 334.9s
# 🧱 Processando batch 279/438
# 📦 Epoch 1, Batch 278/438 | Loss: 503.5911 | Time: 2.07s | ⏳ Est. time left: 331.8s
# 🧱 Processando batch 280/438
# 📦 Epoch 1, Batch 279/438 | Loss: 463.2939 | Time: 2.08s | ⏳ Est. time left: 331.4s
# 🧱 Processando batch 281/438
# 📦 Epoch 1, Batch 280/438 | Loss: 463.8620 | Time: 2.08s | ⏳ Est. time left: 328.5s
# 🧱 Processando batch 282/438
# 📦 Epoch 1, Batch 281/438 | Loss: 412.9727 | Time: 2.07s | ⏳ Est. time left: 325.0s
# 🧱 Processando batch 283/438
# 📦 Epoch 1, Batch 282/438 | Loss: 438.7827 | Time: 2.07s | ⏳ Est. time left: 322.5s
# 🧱 Processando batch 284/438
# 📦 Epoch 1, Batch 283/438 | Loss: 494.0880 | Time: 1.92s | ⏳ Est. time left: 296.9s
# 🧱 Processando batch 285/438
# 📦 Epoch 1, Batch 284/438 | Loss: 514.1789 | Time: 2.21s | ⏳ Est. time left: 339.6s
# 🧱 Processando batch 286/438
# 📦 Epoch 1, Batch 285/438 | Loss: 493.8625 | Time: 2.18s | ⏳ Est. time left: 334.2s
# 🧱 Processando batch 287/438
# 📦 Epoch 1, Batch 286/438 | Loss: 534.4641 | Time: 2.20s | ⏳ Est. time left: 333.9s
# 🧱 Processando batch 288/438
# 📦 Epoch 1, Batch 287/438 | Loss: 527.1535 | Time: 1.91s | ⏳ Est. time left: 288.4s
# 🧱 Processando batch 289/438
# 📦 Epoch 1, Batch 288/438 | Loss: 437.4694 | Time: 2.21s | ⏳ Est. time left: 331.9s
# 🧱 Processando batch 290/438
# 📦 Epoch 1, Batch 289/438 | Loss: 476.6987 | Time: 2.19s | ⏳ Est. time left: 325.6s
# 🧱 Processando batch 291/438
# 📦 Epoch 1, Batch 290/438 | Loss: 531.5065 | Time: 2.24s | ⏳ Est. time left: 331.9s
# 🧱 Processando batch 292/438
# 📦 Epoch 1, Batch 291/438 | Loss: 519.1192 | Time: 2.15s | ⏳ Est. time left: 315.4s
# 🧱 Processando batch 293/438
# 📦 Epoch 1, Batch 292/438 | Loss: 516.7779 | Time: 1.81s | ⏳ Est. time left: 264.9s
# 🧱 Processando batch 294/438
# 📦 Epoch 1, Batch 293/438 | Loss: 509.4186 | Time: 2.26s | ⏳ Est. time left: 327.0s
# 🧱 Processando batch 295/438
# 📦 Epoch 1, Batch 294/438 | Loss: 488.4744 | Time: 2.18s | ⏳ Est. time left: 314.3s
# 🧱 Processando batch 296/438
# 📦 Epoch 1, Batch 295/438 | Loss: 564.0358 | Time: 2.22s | ⏳ Est. time left: 317.1s
# 🧱 Processando batch 297/438
# 📦 Epoch 1, Batch 296/438 | Loss: 590.1003 | Time: 2.21s | ⏳ Est. time left: 314.3s
# 🧱 Processando batch 298/438
# 📦 Epoch 1, Batch 297/438 | Loss: 483.0837 | Time: 2.12s | ⏳ Est. time left: 298.5s
# 🧱 Processando batch 299/438
# 📦 Epoch 1, Batch 298/438 | Loss: 530.4901 | Time: 2.23s | ⏳ Est. time left: 312.8s
# 🧱 Processando batch 300/438
# 📦 Epoch 1, Batch 299/438 | Loss: 491.7100 | Time: 2.21s | ⏳ Est. time left: 307.5s
# 🧱 Processando batch 301/438
# 📦 Epoch 1, Batch 300/438 | Loss: 500.5231 | Time: 2.24s | ⏳ Est. time left: 309.4s
# 🧱 Processando batch 302/438
# 📦 Epoch 1, Batch 301/438 | Loss: 453.9686 | Time: 2.20s | ⏳ Est. time left: 300.9s
# 🧱 Processando batch 303/438
# 📦 Epoch 1, Batch 302/438 | Loss: 459.1760 | Time: 2.20s | ⏳ Est. time left: 299.3s
# 🧱 Processando batch 304/438
# 📦 Epoch 1, Batch 303/438 | Loss: 502.3139 | Time: 2.19s | ⏳ Est. time left: 295.6s
# 🧱 Processando batch 305/438
# 📦 Epoch 1, Batch 304/438 | Loss: 583.3362 | Time: 2.20s | ⏳ Est. time left: 295.1s
# 🧱 Processando batch 306/438
# 📦 Epoch 1, Batch 305/438 | Loss: 484.2410 | Time: 2.22s | ⏳ Est. time left: 294.6s
# 🧱 Processando batch 307/438
# 📦 Epoch 1, Batch 306/438 | Loss: 459.6692 | Time: 2.19s | ⏳ Est. time left: 288.7s
# 🧱 Processando batch 308/438
# 📦 Epoch 1, Batch 307/438 | Loss: 497.9193 | Time: 2.20s | ⏳ Est. time left: 287.8s
# 🧱 Processando batch 309/438
# 📦 Epoch 1, Batch 308/438 | Loss: 474.3800 | Time: 2.18s | ⏳ Est. time left: 283.7s
# 🧱 Processando batch 310/438
# 📦 Epoch 1, Batch 309/438 | Loss: 505.1007 | Time: 2.14s | ⏳ Est. time left: 275.7s
# 🧱 Processando batch 311/438
# 📦 Epoch 1, Batch 310/438 | Loss: 457.2763 | Time: 2.19s | ⏳ Est. time left: 280.7s
# 🧱 Processando batch 312/438
# 📦 Epoch 1, Batch 311/438 | Loss: 490.0072 | Time: 2.19s | ⏳ Est. time left: 277.9s
# 🧱 Processando batch 313/438
# 📦 Epoch 1, Batch 312/438 | Loss: 503.6334 | Time: 2.09s | ⏳ Est. time left: 263.3s
# 🧱 Processando batch 314/438
# 📦 Epoch 1, Batch 313/438 | Loss: 505.2599 | Time: 2.08s | ⏳ Est. time left: 259.9s
# 🧱 Processando batch 315/438
# 📦 Epoch 1, Batch 314/438 | Loss: 397.8495 | Time: 2.07s | ⏳ Est. time left: 256.5s
# 🧱 Processando batch 316/438
# 📦 Epoch 1, Batch 315/438 | Loss: 477.1422 | Time: 2.06s | ⏳ Est. time left: 253.2s
# 🧱 Processando batch 317/438
# 📦 Epoch 1, Batch 316/438 | Loss: 474.7489 | Time: 2.05s | ⏳ Est. time left: 249.7s
# 🧱 Processando batch 318/438
# 📦 Epoch 1, Batch 317/438 | Loss: 547.4947 | Time: 2.06s | ⏳ Est. time left: 248.7s
# 🧱 Processando batch 319/438
# 📦 Epoch 1, Batch 318/438 | Loss: 434.4449 | Time: 2.06s | ⏳ Est. time left: 247.4s
# 🧱 Processando batch 320/438
# 📦 Epoch 1, Batch 319/438 | Loss: 446.2473 | Time: 2.07s | ⏳ Est. time left: 246.6s
# 🧱 Processando batch 321/438
# 📦 Epoch 1, Batch 320/438 | Loss: 551.6205 | Time: 1.78s | ⏳ Est. time left: 210.4s
# 🧱 Processando batch 322/438
# 📦 Epoch 1, Batch 321/438 | Loss: 444.5093 | Time: 2.07s | ⏳ Est. time left: 241.9s
# 🧱 Processando batch 323/438
# 📦 Epoch 1, Batch 322/438 | Loss: 512.6107 | Time: 2.06s | ⏳ Est. time left: 239.1s
# 🧱 Processando batch 324/438
# 📦 Epoch 1, Batch 323/438 | Loss: 479.3275 | Time: 1.79s | ⏳ Est. time left: 206.1s
# 🧱 Processando batch 325/438
# 📦 Epoch 1, Batch 324/438 | Loss: 488.7924 | Time: 2.07s | ⏳ Est. time left: 235.8s
# 🧱 Processando batch 326/438
# 📦 Epoch 1, Batch 325/438 | Loss: 457.9300 | Time: 2.06s | ⏳ Est. time left: 233.0s
# 🧱 Processando batch 327/438
# 📦 Epoch 1, Batch 326/438 | Loss: 501.2966 | Time: 2.06s | ⏳ Est. time left: 230.9s
# 🧱 Processando batch 328/438
# 📦 Epoch 1, Batch 327/438 | Loss: 477.3052 | Time: 2.06s | ⏳ Est. time left: 228.2s
# 🧱 Processando batch 329/438
# 📦 Epoch 1, Batch 328/438 | Loss: 509.1345 | Time: 2.06s | ⏳ Est. time left: 226.5s
# 🧱 Processando batch 330/438
# 📦 Epoch 1, Batch 329/438 | Loss: 478.2789 | Time: 2.05s | ⏳ Est. time left: 223.7s
# 🧱 Processando batch 331/438
# 📦 Epoch 1, Batch 330/438 | Loss: 480.7974 | Time: 1.78s | ⏳ Est. time left: 191.7s
# 🧱 Processando batch 332/438
# 📦 Epoch 1, Batch 331/438 | Loss: 448.4410 | Time: 2.05s | ⏳ Est. time left: 219.5s
# 🧱 Processando batch 333/438
# 📦 Epoch 1, Batch 332/438 | Loss: 514.3680 | Time: 2.05s | ⏳ Est. time left: 217.2s
# 🧱 Processando batch 334/438
# 📦 Epoch 1, Batch 333/438 | Loss: 508.0921 | Time: 2.06s | ⏳ Est. time left: 216.2s
# 🧱 Processando batch 335/438
# 📦 Epoch 1, Batch 334/438 | Loss: 458.8880 | Time: 2.07s | ⏳ Est. time left: 215.7s
# 🧱 Processando batch 336/438
# 📦 Epoch 1, Batch 335/438 | Loss: 534.5840 | Time: 2.07s | ⏳ Est. time left: 213.7s
# 🧱 Processando batch 337/438
# 📦 Epoch 1, Batch 336/438 | Loss: 474.7911 | Time: 2.06s | ⏳ Est. time left: 210.1s
# 🧱 Processando batch 338/438
# 📦 Epoch 1, Batch 337/438 | Loss: 483.6623 | Time: 2.11s | ⏳ Est. time left: 213.0s
# 🧱 Processando batch 339/438
# 📦 Epoch 1, Batch 338/438 | Loss: 533.2401 | Time: 2.09s | ⏳ Est. time left: 208.9s
# 🧱 Processando batch 340/438
# 📦 Epoch 1, Batch 339/438 | Loss: 515.2935 | Time: 1.96s | ⏳ Est. time left: 194.0s
# 🧱 Processando batch 341/438
# 📦 Epoch 1, Batch 340/438 | Loss: 474.6893 | Time: 1.71s | ⏳ Est. time left: 167.2s
# 🧱 Processando batch 342/438
# 📦 Epoch 1, Batch 341/438 | Loss: 562.2146 | Time: 1.95s | ⏳ Est. time left: 188.9s
# 🧱 Processando batch 343/438
# 📦 Epoch 1, Batch 342/438 | Loss: 510.5126 | Time: 1.96s | ⏳ Est. time left: 188.6s
# 🧱 Processando batch 344/438
# 📦 Epoch 1, Batch 343/438 | Loss: 471.7565 | Time: 1.97s | ⏳ Est. time left: 187.2s
# 🧱 Processando batch 345/438
# 📦 Epoch 1, Batch 344/438 | Loss: 476.4012 | Time: 2.03s | ⏳ Est. time left: 190.5s
# 🧱 Processando batch 346/438
# 📦 Epoch 1, Batch 345/438 | Loss: 482.6843 | Time: 1.97s | ⏳ Est. time left: 183.6s
# 🧱 Processando batch 347/438
# 📦 Epoch 1, Batch 346/438 | Loss: 503.9354 | Time: 2.16s | ⏳ Est. time left: 198.4s
# 🧱 Processando batch 348/438
# 📦 Epoch 1, Batch 347/438 | Loss: 497.2540 | Time: 2.11s | ⏳ Est. time left: 192.1s
# 🧱 Processando batch 349/438
# 📦 Epoch 1, Batch 348/438 | Loss: 474.7740 | Time: 2.13s | ⏳ Est. time left: 191.6s
# 🧱 Processando batch 350/438
# 📦 Epoch 1, Batch 349/438 | Loss: 445.9387 | Time: 2.07s | ⏳ Est. time left: 184.0s
# 🧱 Processando batch 351/438
# 📦 Epoch 1, Batch 350/438 | Loss: 515.6316 | Time: 2.06s | ⏳ Est. time left: 181.2s
# 🧱 Processando batch 352/438
# 📦 Epoch 1, Batch 351/438 | Loss: 450.8614 | Time: 2.06s | ⏳ Est. time left: 179.1s
# 🧱 Processando batch 353/438
# 📦 Epoch 1, Batch 352/438 | Loss: 505.0305 | Time: 2.06s | ⏳ Est. time left: 177.5s
# 🧱 Processando batch 354/438
# 📦 Epoch 1, Batch 353/438 | Loss: 481.0785 | Time: 2.06s | ⏳ Est. time left: 175.2s
# 🧱 Processando batch 355/438
# 📦 Epoch 1, Batch 354/438 | Loss: 462.1991 | Time: 2.06s | ⏳ Est. time left: 172.9s
# 🧱 Processando batch 356/438
# 📦 Epoch 1, Batch 355/438 | Loss: 498.7498 | Time: 2.06s | ⏳ Est. time left: 171.0s
# 🧱 Processando batch 357/438
# 📦 Epoch 1, Batch 356/438 | Loss: 447.3231 | Time: 2.06s | ⏳ Est. time left: 168.9s
# 🧱 Processando batch 358/438
# 📦 Epoch 1, Batch 357/438 | Loss: 505.7007 | Time: 2.07s | ⏳ Est. time left: 167.7s
# 🧱 Processando batch 359/438
# 📦 Epoch 1, Batch 358/438 | Loss: 520.6589 | Time: 2.08s | ⏳ Est. time left: 166.2s
# 🧱 Processando batch 360/438
# 📦 Epoch 1, Batch 359/438 | Loss: 453.8302 | Time: 2.13s | ⏳ Est. time left: 168.2s
# 🧱 Processando batch 361/438
# 📦 Epoch 1, Batch 360/438 | Loss: 531.7890 | Time: 2.07s | ⏳ Est. time left: 161.2s
# 🧱 Processando batch 362/438
# 📦 Epoch 1, Batch 361/438 | Loss: 484.1262 | Time: 2.12s | ⏳ Est. time left: 163.5s
# 🧱 Processando batch 363/438
# 📦 Epoch 1, Batch 362/438 | Loss: 491.2982 | Time: 2.07s | ⏳ Est. time left: 157.2s
# 🧱 Processando batch 364/438
# 📦 Epoch 1, Batch 363/438 | Loss: 436.3253 | Time: 2.05s | ⏳ Est. time left: 153.4s
# 🧱 Processando batch 365/438
# 📦 Epoch 1, Batch 364/438 | Loss: 470.7103 | Time: 2.05s | ⏳ Est. time left: 151.7s
# 🧱 Processando batch 366/438
# 📦 Epoch 1, Batch 365/438 | Loss: 473.1872 | Time: 2.06s | ⏳ Est. time left: 150.4s
# 🧱 Processando batch 367/438
# 📦 Epoch 1, Batch 366/438 | Loss: 508.6306 | Time: 2.08s | ⏳ Est. time left: 149.6s
# 🧱 Processando batch 368/438
# 📦 Epoch 1, Batch 367/438 | Loss: 447.9327 | Time: 2.06s | ⏳ Est. time left: 146.0s
# 🧱 Processando batch 369/438
# 📦 Epoch 1, Batch 368/438 | Loss: 474.3734 | Time: 2.10s | ⏳ Est. time left: 146.9s
# 🧱 Processando batch 370/438
# 📦 Epoch 1, Batch 369/438 | Loss: 498.1595 | Time: 2.05s | ⏳ Est. time left: 141.7s
# 🧱 Processando batch 371/438
# 📦 Epoch 1, Batch 370/438 | Loss: 446.3201 | Time: 2.14s | ⏳ Est. time left: 145.5s
# 🧱 Processando batch 372/438
# 📦 Epoch 1, Batch 371/438 | Loss: 456.3634 | Time: 2.12s | ⏳ Est. time left: 141.7s
# 🧱 Processando batch 373/438
# 📦 Epoch 1, Batch 372/438 | Loss: 489.5858 | Time: 2.08s | ⏳ Est. time left: 137.6s
# 🧱 Processando batch 374/438
# 📦 Epoch 1, Batch 373/438 | Loss: 423.9643 | Time: 2.06s | ⏳ Est. time left: 133.8s
# 🧱 Processando batch 375/438
# 📦 Epoch 1, Batch 374/438 | Loss: 458.6396 | Time: 2.09s | ⏳ Est. time left: 133.6s
# 🧱 Processando batch 376/438
# 📦 Epoch 1, Batch 375/438 | Loss: 521.6905 | Time: 2.07s | ⏳ Est. time left: 130.2s
# 🧱 Processando batch 377/438
# 📦 Epoch 1, Batch 376/438 | Loss: 448.6982 | Time: 2.06s | ⏳ Est. time left: 127.7s
# 🧱 Processando batch 378/438
# 📦 Epoch 1, Batch 377/438 | Loss: 491.8618 | Time: 2.04s | ⏳ Est. time left: 124.6s
# 🧱 Processando batch 379/438
# 📦 Epoch 1, Batch 378/438 | Loss: 498.7082 | Time: 2.06s | ⏳ Est. time left: 123.5s
# 🧱 Processando batch 380/438
# 📦 Epoch 1, Batch 379/438 | Loss: 518.6978 | Time: 2.07s | ⏳ Est. time left: 122.0s
# 🧱 Processando batch 381/438
# 📦 Epoch 1, Batch 380/438 | Loss: 498.4956 | Time: 2.06s | ⏳ Est. time left: 119.3s
# 🧱 Processando batch 382/438
# 📦 Epoch 1, Batch 381/438 | Loss: 469.5183 | Time: 2.07s | ⏳ Est. time left: 117.8s
# 🧱 Processando batch 383/438
# 📦 Epoch 1, Batch 382/438 | Loss: 509.6885 | Time: 2.05s | ⏳ Est. time left: 115.0s
# 🧱 Processando batch 384/438
# 📦 Epoch 1, Batch 383/438 | Loss: 480.6424 | Time: 2.07s | ⏳ Est. time left: 113.8s
# 🧱 Processando batch 385/438
# 📦 Epoch 1, Batch 384/438 | Loss: 491.6707 | Time: 2.08s | ⏳ Est. time left: 112.2s
# 🧱 Processando batch 386/438
# 📦 Epoch 1, Batch 385/438 | Loss: 500.5057 | Time: 2.06s | ⏳ Est. time left: 109.3s
# 🧱 Processando batch 387/438
# 📦 Epoch 1, Batch 386/438 | Loss: 457.0984 | Time: 2.05s | ⏳ Est. time left: 106.7s
# 🧱 Processando batch 388/438
# 📦 Epoch 1, Batch 387/438 | Loss: 484.3165 | Time: 2.06s | ⏳ Est. time left: 105.1s
# 🧱 Processando batch 389/438
# 📦 Epoch 1, Batch 388/438 | Loss: 492.6779 | Time: 1.79s | ⏳ Est. time left: 89.3s
# 🧱 Processando batch 390/438
# 📦 Epoch 1, Batch 389/438 | Loss: 458.8021 | Time: 2.15s | ⏳ Est. time left: 105.1s
# 🧱 Processando batch 391/438
# 📦 Epoch 1, Batch 390/438 | Loss: 513.0843 | Time: 2.18s | ⏳ Est. time left: 104.7s
# 🧱 Processando batch 392/438
# 📦 Epoch 1, Batch 391/438 | Loss: 452.2213 | Time: 2.19s | ⏳ Est. time left: 103.0s
# 🧱 Processando batch 393/438
# 📦 Epoch 1, Batch 392/438 | Loss: 509.2146 | Time: 2.19s | ⏳ Est. time left: 100.6s
# 🧱 Processando batch 394/438
# 📦 Epoch 1, Batch 393/438 | Loss: 474.1618 | Time: 2.19s | ⏳ Est. time left: 98.5s
# 🧱 Processando batch 395/438
# 📦 Epoch 1, Batch 394/438 | Loss: 506.4290 | Time: 2.30s | ⏳ Est. time left: 101.2s
# 🧱 Processando batch 396/438
# 📦 Epoch 1, Batch 395/438 | Loss: 482.8368 | Time: 2.22s | ⏳ Est. time left: 95.4s
# 🧱 Processando batch 397/438
# 📦 Epoch 1, Batch 396/438 | Loss: 489.0807 | Time: 2.22s | ⏳ Est. time left: 93.3s
# 🧱 Processando batch 398/438
# 📦 Epoch 1, Batch 397/438 | Loss: 506.8697 | Time: 2.24s | ⏳ Est. time left: 92.0s
# 🧱 Processando batch 399/438
# 📦 Epoch 1, Batch 398/438 | Loss: 475.3842 | Time: 2.22s | ⏳ Est. time left: 88.7s
# 🧱 Processando batch 400/438
# 📦 Epoch 1, Batch 399/438 | Loss: 511.0154 | Time: 1.89s | ⏳ Est. time left: 73.6s
# 🧱 Processando batch 401/438
# 📦 Epoch 1, Batch 400/438 | Loss: 503.4151 | Time: 2.23s | ⏳ Est. time left: 84.7s
# 🧱 Processando batch 402/438
# 📦 Epoch 1, Batch 401/438 | Loss: 499.3171 | Time: 2.24s | ⏳ Est. time left: 82.7s
# 🧱 Processando batch 403/438
# 📦 Epoch 1, Batch 402/438 | Loss: 528.7244 | Time: 2.24s | ⏳ Est. time left: 80.8s
# 🧱 Processando batch 404/438
# 📦 Epoch 1, Batch 403/438 | Loss: 492.0566 | Time: 2.22s | ⏳ Est. time left: 77.6s
# 🧱 Processando batch 405/438
# 📦 Epoch 1, Batch 404/438 | Loss: 420.5030 | Time: 2.20s | ⏳ Est. time left: 74.8s
# 🧱 Processando batch 406/438
# 📦 Epoch 1, Batch 405/438 | Loss: 475.3333 | Time: 2.19s | ⏳ Est. time left: 72.3s
# 🧱 Processando batch 407/438
# 📦 Epoch 1, Batch 406/438 | Loss: 453.3189 | Time: 2.22s | ⏳ Est. time left: 70.9s
# 🧱 Processando batch 408/438
# 📦 Epoch 1, Batch 407/438 | Loss: 470.8958 | Time: 2.19s | ⏳ Est. time left: 67.9s
# 🧱 Processando batch 409/438
# 📦 Epoch 1, Batch 408/438 | Loss: 418.1981 | Time: 2.18s | ⏳ Est. time left: 65.5s
# 🧱 Processando batch 410/438
# 📦 Epoch 1, Batch 409/438 | Loss: 435.2007 | Time: 2.18s | ⏳ Est. time left: 63.3s
# 🧱 Processando batch 411/438
# 📦 Epoch 1, Batch 410/438 | Loss: 486.8553 | Time: 2.12s | ⏳ Est. time left: 59.3s
# 🧱 Processando batch 412/438
# 📦 Epoch 1, Batch 411/438 | Loss: 466.1799 | Time: 2.18s | ⏳ Est. time left: 58.8s
# 🧱 Processando batch 413/438
# 📦 Epoch 1, Batch 412/438 | Loss: 487.2610 | Time: 2.18s | ⏳ Est. time left: 56.6s
# 🧱 Processando batch 414/438
# 📦 Epoch 1, Batch 413/438 | Loss: 489.5394 | Time: 2.17s | ⏳ Est. time left: 54.3s
# 🧱 Processando batch 415/438
# 📦 Epoch 1, Batch 414/438 | Loss: 499.2884 | Time: 2.14s | ⏳ Est. time left: 51.5s
# 🧱 Processando batch 416/438
# 📦 Epoch 1, Batch 415/438 | Loss: 472.9967 | Time: 2.19s | ⏳ Est. time left: 50.3s
# 🧱 Processando batch 417/438
# 📦 Epoch 1, Batch 416/438 | Loss: 505.2869 | Time: 2.17s | ⏳ Est. time left: 47.7s
# 🧱 Processando batch 418/438
# 📦 Epoch 1, Batch 417/438 | Loss: 541.3599 | Time: 2.18s | ⏳ Est. time left: 45.8s
# 🧱 Processando batch 419/438
# 📦 Epoch 1, Batch 418/438 | Loss: 456.9896 | Time: 2.19s | ⏳ Est. time left: 43.8s
# 🧱 Processando batch 420/438
# 📦 Epoch 1, Batch 419/438 | Loss: 475.8540 | Time: 2.18s | ⏳ Est. time left: 41.4s
# 🧱 Processando batch 421/438
# 📦 Epoch 1, Batch 420/438 | Loss: 447.2080 | Time: 2.18s | ⏳ Est. time left: 39.2s
# 🧱 Processando batch 422/438
# 📦 Epoch 1, Batch 421/438 | Loss: 489.5500 | Time: 2.19s | ⏳ Est. time left: 37.2s
# 🧱 Processando batch 423/438
# 📦 Epoch 1, Batch 422/438 | Loss: 529.1526 | Time: 2.17s | ⏳ Est. time left: 34.7s
# 🧱 Processando batch 424/438
# 📦 Epoch 1, Batch 423/438 | Loss: 492.1038 | Time: 2.18s | ⏳ Est. time left: 32.7s
# 🧱 Processando batch 425/438
# 📦 Epoch 1, Batch 424/438 | Loss: 475.0554 | Time: 2.18s | ⏳ Est. time left: 30.5s
# 🧱 Processando batch 426/438
# 📦 Epoch 1, Batch 425/438 | Loss: 446.5108 | Time: 2.18s | ⏳ Est. time left: 28.4s
# 🧱 Processando batch 427/438
# 📦 Epoch 1, Batch 426/438 | Loss: 468.5092 | Time: 2.20s | ⏳ Est. time left: 26.4s
# 🧱 Processando batch 428/438
# 📦 Epoch 1, Batch 427/438 | Loss: 487.0914 | Time: 2.18s | ⏳ Est. time left: 24.0s
# 🧱 Processando batch 429/438
# ...
# 📦 Epoch 6, Batch 111/438 | Loss: 266.3777 | Time: 2.18s | ⏳ Est. time left: 712.9s
# 🧱 Processando batch 113/438
# 📦 Epoch 6, Batch 112/438 | Loss: 230.2153 | Time: 2.18s | ⏳ Est. time left: 711.0s
# 🧱 Processando batch 114/438
# 📦 Epoch 6, Batch 113/438 | Loss: 256.1626 | Time: 2.19s | ⏳ Est. time left: 711.4s
# 🧱 Processando batch 115/438
# 📦 Epoch 6, Batch 114/438 | Loss: 218.1661 | Time: 2.21s | ⏳ Est. time left: 717.1s
# 🧱 Processando batch 116/438
# 📦 Epoch 6, Batch 115/438 | Loss: 274.2088 | Time: 2.19s | ⏳ Est. time left: 706.7s
# 🧱 Processando batch 117/438
# 📦 Epoch 6, Batch 116/438 | Loss: 269.5766 | Time: 2.18s | ⏳ Est. time left: 701.7s
# 🧱 Processando batch 118/438
# 📦 Epoch 6, Batch 117/438 | Loss: 306.3484 | Time: 2.19s | ⏳ Est. time left: 701.9s
# 🧱 Processando batch 119/438
# 📦 Epoch 6, Batch 118/438 | Loss: 235.5410 | Time: 2.18s | ⏳ Est. time left: 696.3s
# 🧱 Processando batch 120/438
# 📦 Epoch 6, Batch 119/438 | Loss: 264.6601 | Time: 2.18s | ⏳ Est. time left: 696.0s
# 🧱 Processando batch 121/438
# 📦 Epoch 6, Batch 120/438 | Loss: 266.5430 | Time: 2.18s | ⏳ Est. time left: 693.6s
# 🧱 Processando batch 122/438
# 📦 Epoch 6, Batch 121/438 | Loss: 242.1219 | Time: 2.19s | ⏳ Est. time left: 694.9s
# 🧱 Processando batch 123/438
# 📦 Epoch 6, Batch 122/438 | Loss: 220.4431 | Time: 2.18s | ⏳ Est. time left: 690.3s
# 🧱 Processando batch 124/438
# 📦 Epoch 6, Batch 123/438 | Loss: 229.0920 | Time: 2.18s | ⏳ Est. time left: 686.8s
# 🧱 Processando batch 125/438
# 📦 Epoch 6, Batch 124/438 | Loss: 224.2395 | Time: 2.26s | ⏳ Est. time left: 708.3s
# 🧱 Processando batch 126/438
# 📦 Epoch 6, Batch 125/438 | Loss: 264.0791 | Time: 2.32s | ⏳ Est. time left: 725.1s
# 🧱 Processando batch 127/438
# 📦 Epoch 6, Batch 126/438 | Loss: 267.0185 | Time: 2.34s | ⏳ Est. time left: 730.8s
# 🧱 Processando batch 128/438
# 📦 Epoch 6, Batch 127/438 | Loss: 263.5519 | Time: 2.34s | ⏳ Est. time left: 727.7s
# 🧱 Processando batch 129/438
# 📦 Epoch 6, Batch 128/438 | Loss: 218.9588 | Time: 2.36s | ⏳ Est. time left: 730.8s
# 🧱 Processando batch 130/438
# 📦 Epoch 6, Batch 129/438 | Loss: 219.0581 | Time: 2.34s | ⏳ Est. time left: 724.4s
# 🧱 Processando batch 131/438
# 📦 Epoch 6, Batch 130/438 | Loss: 208.7870 | Time: 2.35s | ⏳ Est. time left: 725.1s
# 🧱 Processando batch 132/438
# 📦 Epoch 6, Batch 131/438 | Loss: 216.7659 | Time: 2.39s | ⏳ Est. time left: 733.1s
# 🧱 Processando batch 133/438
# 📦 Epoch 6, Batch 132/438 | Loss: 235.8441 | Time: 2.39s | ⏳ Est. time left: 732.9s
# 🧱 Processando batch 134/438
# 📦 Epoch 6, Batch 133/438 | Loss: 276.6291 | Time: 2.39s | ⏳ Est. time left: 730.4s
# 🧱 Processando batch 135/438
# 📦 Epoch 6, Batch 134/438 | Loss: 226.3609 | Time: 2.36s | ⏳ Est. time left: 717.7s
# 🧱 Processando batch 136/438
# 📦 Epoch 6, Batch 135/438 | Loss: 224.8334 | Time: 2.37s | ⏳ Est. time left: 716.8s
# 🧱 Processando batch 137/438
# 📦 Epoch 6, Batch 136/438 | Loss: 263.7326 | Time: 2.37s | ⏳ Est. time left: 714.5s
# 🧱 Processando batch 138/438
# 📦 Epoch 6, Batch 137/438 | Loss: 249.8645 | Time: 2.37s | ⏳ Est. time left: 712.7s
# 🧱 Processando batch 139/438
# 📦 Epoch 6, Batch 138/438 | Loss: 213.4724 | Time: 2.36s | ⏳ Est. time left: 708.6s
# 🧱 Processando batch 140/438
# 📦 Epoch 6, Batch 139/438 | Loss: 294.2498 | Time: 2.30s | ⏳ Est. time left: 686.7s
# 🧱 Processando batch 141/438
# 📦 Epoch 6, Batch 140/438 | Loss: 270.8364 | Time: 2.32s | ⏳ Est. time left: 692.8s
# 🧱 Processando batch 142/438
# 📦 Epoch 6, Batch 141/438 | Loss: 284.0621 | Time: 2.24s | ⏳ Est. time left: 664.5s
# 🧱 Processando batch 143/438
# 📦 Epoch 6, Batch 142/438 | Loss: 244.7386 | Time: 2.24s | ⏳ Est. time left: 663.9s
# 🧱 Processando batch 144/438
# 📦 Epoch 6, Batch 143/438 | Loss: 278.4406 | Time: 2.22s | ⏳ Est. time left: 654.5s
# 🧱 Processando batch 145/438
# 📦 Epoch 6, Batch 144/438 | Loss: 272.6104 | Time: 2.31s | ⏳ Est. time left: 679.9s
# 🧱 Processando batch 146/438
# 📦 Epoch 6, Batch 145/438 | Loss: 288.4105 | Time: 2.31s | ⏳ Est. time left: 677.1s
# 🧱 Processando batch 147/438
# 📦 Epoch 6, Batch 146/438 | Loss: 229.9560 | Time: 2.34s | ⏳ Est. time left: 683.6s
# 🧱 Processando batch 148/438
# 📦 Epoch 6, Batch 147/438 | Loss: 325.2045 | Time: 2.24s | ⏳ Est. time left: 650.8s
# 🧱 Processando batch 149/438
# 📦 Epoch 6, Batch 148/438 | Loss: 241.3220 | Time: 2.23s | ⏳ Est. time left: 645.8s
# 🧱 Processando batch 150/438
# 📦 Epoch 6, Batch 149/438 | Loss: 289.5739 | Time: 2.25s | ⏳ Est. time left: 651.3s
# 🧱 Processando batch 151/438
# 📦 Epoch 6, Batch 150/438 | Loss: 273.1730 | Time: 2.26s | ⏳ Est. time left: 651.1s
# 🧱 Processando batch 152/438
# 📦 Epoch 6, Batch 151/438 | Loss: 251.1317 | Time: 2.21s | ⏳ Est. time left: 634.7s
# 🧱 Processando batch 153/438
# 📦 Epoch 6, Batch 152/438 | Loss: 243.8595 | Time: 2.20s | ⏳ Est. time left: 628.6s
# 🧱 Processando batch 154/438
# 📦 Epoch 6, Batch 153/438 | Loss: 224.7130 | Time: 2.21s | ⏳ Est. time left: 629.4s
# 🧱 Processando batch 155/438
# 📦 Epoch 6, Batch 154/438 | Loss: 239.2300 | Time: 2.20s | ⏳ Est. time left: 624.2s
# 🧱 Processando batch 156/438
# 📦 Epoch 6, Batch 155/438 | Loss: 297.4326 | Time: 2.19s | ⏳ Est. time left: 620.4s
# 🧱 Processando batch 157/438
# 📦 Epoch 6, Batch 156/438 | Loss: 250.4306 | Time: 2.20s | ⏳ Est. time left: 620.8s
# 🧱 Processando batch 158/438
# 📦 Epoch 6, Batch 157/438 | Loss: 248.6808 | Time: 2.20s | ⏳ Est. time left: 618.6s
# 🧱 Processando batch 159/438
# 📦 Epoch 6, Batch 158/438 | Loss: 230.1645 | Time: 2.20s | ⏳ Est. time left: 615.3s
# 🧱 Processando batch 160/438
# 📦 Epoch 6, Batch 159/438 | Loss: 283.4713 | Time: 2.21s | ⏳ Est. time left: 616.4s
# 🧱 Processando batch 161/438
# 📦 Epoch 6, Batch 160/438 | Loss: 291.7641 | Time: 1.90s | ⏳ Est. time left: 528.6s
# 🧱 Processando batch 162/438
# 📦 Epoch 6, Batch 161/438 | Loss: 240.8927 | Time: 2.22s | ⏳ Est. time left: 614.2s
# 🧱 Processando batch 163/438
# 📦 Epoch 6, Batch 162/438 | Loss: 281.9470 | Time: 2.19s | ⏳ Est. time left: 604.7s
# 🧱 Processando batch 164/438
# 📦 Epoch 6, Batch 163/438 | Loss: 271.4613 | Time: 2.19s | ⏳ Est. time left: 602.3s
# 🧱 Processando batch 165/438
# 📦 Epoch 6, Batch 164/438 | Loss: 274.4355 | Time: 2.19s | ⏳ Est. time left: 601.0s
# 🧱 Processando batch 166/438
# 📦 Epoch 6, Batch 165/438 | Loss: 356.9229 | Time: 2.20s | ⏳ Est. time left: 600.8s
# 🧱 Processando batch 167/438
# 📦 Epoch 6, Batch 166/438 | Loss: 230.8260 | Time: 2.32s | ⏳ Est. time left: 631.6s
# 🧱 Processando batch 168/438
# 📦 Epoch 6, Batch 167/438 | Loss: 314.0149 | Time: 2.26s | ⏳ Est. time left: 611.8s
# 🧱 Processando batch 169/438
# 📦 Epoch 6, Batch 168/438 | Loss: 274.8211 | Time: 2.21s | ⏳ Est. time left: 597.7s
# 🧱 Processando batch 170/438
# 📦 Epoch 6, Batch 169/438 | Loss: 215.9960 | Time: 2.00s | ⏳ Est. time left: 539.1s
# 🧱 Processando batch 171/438
# 📦 Epoch 6, Batch 170/438 | Loss: 195.3492 | Time: 2.25s | ⏳ Est. time left: 603.8s
# 🧱 Processando batch 172/438
# 📦 Epoch 6, Batch 171/438 | Loss: 272.8814 | Time: 1.93s | ⏳ Est. time left: 515.3s
# 🧱 Processando batch 173/438
# 📦 Epoch 6, Batch 172/438 | Loss: 265.3561 | Time: 2.22s | ⏳ Est. time left: 591.8s
# 🧱 Processando batch 174/438
# 📦 Epoch 6, Batch 173/438 | Loss: 234.0653 | Time: 2.25s | ⏳ Est. time left: 596.3s
# 🧱 Processando batch 175/438
# 📦 Epoch 6, Batch 174/438 | Loss: 304.1532 | Time: 2.31s | ⏳ Est. time left: 609.3s
# 🧱 Processando batch 176/438
# 📦 Epoch 6, Batch 175/438 | Loss: 233.0000 | Time: 2.19s | ⏳ Est. time left: 576.0s
# 🧱 Processando batch 177/438
# 📦 Epoch 6, Batch 176/438 | Loss: 218.2896 | Time: 2.17s | ⏳ Est. time left: 568.4s
# 🧱 Processando batch 178/438
# 📦 Epoch 6, Batch 177/438 | Loss: 346.4371 | Time: 2.18s | ⏳ Est. time left: 569.0s
# 🧱 Processando batch 179/438
# 📦 Epoch 6, Batch 178/438 | Loss: 275.6968 | Time: 2.21s | ⏳ Est. time left: 575.7s
# 🧱 Processando batch 180/438
# 📦 Epoch 6, Batch 179/438 | Loss: 245.2863 | Time: 2.18s | ⏳ Est. time left: 564.8s
# 🧱 Processando batch 181/438
# 📦 Epoch 6, Batch 180/438 | Loss: 229.0606 | Time: 2.19s | ⏳ Est. time left: 564.5s
# 🧱 Processando batch 182/438
# 📦 Epoch 6, Batch 181/438 | Loss: 276.5559 | Time: 2.18s | ⏳ Est. time left: 559.1s
# 🧱 Processando batch 183/438
# 📦 Epoch 6, Batch 182/438 | Loss: 217.1783 | Time: 2.20s | ⏳ Est. time left: 564.4s
# 🧱 Processando batch 184/438
# 📦 Epoch 6, Batch 183/438 | Loss: 277.1928 | Time: 2.18s | ⏳ Est. time left: 555.9s
# 🧱 Processando batch 185/438
# 📦 Epoch 6, Batch 184/438 | Loss: 219.8341 | Time: 2.20s | ⏳ Est. time left: 557.6s
# 🧱 Processando batch 186/438
# 📦 Epoch 6, Batch 185/438 | Loss: 292.6262 | Time: 2.19s | ⏳ Est. time left: 553.1s
# 🧱 Processando batch 187/438
# 📦 Epoch 6, Batch 186/438 | Loss: 239.2185 | Time: 2.20s | ⏳ Est. time left: 555.0s
# 🧱 Processando batch 188/438
# 📦 Epoch 6, Batch 187/438 | Loss: 256.2874 | Time: 2.33s | ⏳ Est. time left: 583.7s
# 🧱 Processando batch 189/438
# 📦 Epoch 6, Batch 188/438 | Loss: 260.1010 | Time: 2.27s | ⏳ Est. time left: 568.3s
# 🧱 Processando batch 190/438
# 📦 Epoch 6, Batch 189/438 | Loss: 288.3657 | Time: 2.28s | ⏳ Est. time left: 568.7s
# 🧱 Processando batch 191/438
# 📦 Epoch 6, Batch 190/438 | Loss: 213.6715 | Time: 2.30s | ⏳ Est. time left: 569.3s
# 🧱 Processando batch 192/438
# 📦 Epoch 6, Batch 191/438 | Loss: 244.3960 | Time: 2.26s | ⏳ Est. time left: 558.5s
# 🧱 Processando batch 193/438
# 📦 Epoch 6, Batch 192/438 | Loss: 225.7077 | Time: 2.29s | ⏳ Est. time left: 563.0s
# 🧱 Processando batch 194/438
# 📦 Epoch 6, Batch 193/438 | Loss: 261.3735 | Time: 2.33s | ⏳ Est. time left: 570.2s
# 🧱 Processando batch 195/438
# 📦 Epoch 6, Batch 194/438 | Loss: 263.3542 | Time: 2.34s | ⏳ Est. time left: 571.9s
# 🧱 Processando batch 196/438
# 📦 Epoch 6, Batch 195/438 | Loss: 248.2878 | Time: 2.33s | ⏳ Est. time left: 567.0s
# 🧱 Processando batch 197/438
# 📦 Epoch 6, Batch 196/438 | Loss: 223.9920 | Time: 2.24s | ⏳ Est. time left: 542.1s
# 🧱 Processando batch 198/438
# 📦 Epoch 6, Batch 197/438 | Loss: 221.8887 | Time: 2.22s | ⏳ Est. time left: 533.9s
# 🧱 Processando batch 199/438
# 📦 Epoch 6, Batch 198/438 | Loss: 284.3403 | Time: 2.32s | ⏳ Est. time left: 556.8s
# 🧱 Processando batch 200/438
# 📦 Epoch 6, Batch 199/438 | Loss: 266.1538 | Time: 2.26s | ⏳ Est. time left: 540.1s
# 🧱 Processando batch 201/438
# 📦 Epoch 6, Batch 200/438 | Loss: 268.0278 | Time: 2.28s | ⏳ Est. time left: 541.9s
# 🧱 Processando batch 202/438
# 📦 Epoch 6, Batch 201/438 | Loss: 256.5641 | Time: 2.23s | ⏳ Est. time left: 528.1s
# 🧱 Processando batch 203/438
# 📦 Epoch 6, Batch 202/438 | Loss: 222.6817 | Time: 2.28s | ⏳ Est. time left: 538.6s
# 🧱 Processando batch 204/438
# 📦 Epoch 6, Batch 203/438 | Loss: 259.3527 | Time: 2.39s | ⏳ Est. time left: 561.0s
# 🧱 Processando batch 205/438
# 📦 Epoch 6, Batch 204/438 | Loss: 240.0003 | Time: 2.31s | ⏳ Est. time left: 539.4s
# 🧱 Processando batch 206/438
# 📦 Epoch 6, Batch 205/438 | Loss: 294.5501 | Time: 2.25s | ⏳ Est. time left: 523.3s
# 🧱 Processando batch 207/438
# 📦 Epoch 6, Batch 206/438 | Loss: 216.9718 | Time: 2.24s | ⏳ Est. time left: 518.8s
# 🧱 Processando batch 208/438
# 📦 Epoch 6, Batch 207/438 | Loss: 275.3753 | Time: 2.29s | ⏳ Est. time left: 528.7s
# 🧱 Processando batch 209/438
# 📦 Epoch 6, Batch 208/438 | Loss: 247.8508 | Time: 2.23s | ⏳ Est. time left: 513.8s
# 🧱 Processando batch 210/438
# 📦 Epoch 6, Batch 209/438 | Loss: 200.9944 | Time: 2.31s | ⏳ Est. time left: 528.0s
# 🧱 Processando batch 211/438
# 📦 Epoch 6, Batch 210/438 | Loss: 253.9427 | Time: 2.32s | ⏳ Est. time left: 529.4s
# 🧱 Processando batch 212/438
# 📦 Epoch 6, Batch 211/438 | Loss: 235.7231 | Time: 2.32s | ⏳ Est. time left: 526.4s
# 🧱 Processando batch 213/438
# 📦 Epoch 6, Batch 212/438 | Loss: 233.1449 | Time: 2.26s | ⏳ Est. time left: 510.9s
# 🧱 Processando batch 214/438
# 📦 Epoch 6, Batch 213/438 | Loss: 256.2417 | Time: 2.33s | ⏳ Est. time left: 523.8s
# 🧱 Processando batch 215/438
# 📦 Epoch 6, Batch 214/438 | Loss: 228.9051 | Time: 1.94s | ⏳ Est. time left: 434.2s
# 🧱 Processando batch 216/438
# 📦 Epoch 6, Batch 215/438 | Loss: 270.2671 | Time: 2.22s | ⏳ Est. time left: 494.2s
# 🧱 Processando batch 217/438
# 📦 Epoch 6, Batch 216/438 | Loss: 246.6835 | Time: 2.31s | ⏳ Est. time left: 512.4s
# 🧱 Processando batch 218/438
# 📦 Epoch 6, Batch 217/438 | Loss: 303.3820 | Time: 2.38s | ⏳ Est. time left: 526.1s
# 🧱 Processando batch 219/438
# 📦 Epoch 6, Batch 218/438 | Loss: 221.3822 | Time: 2.32s | ⏳ Est. time left: 509.4s
# 🧱 Processando batch 220/438
# 📦 Epoch 6, Batch 219/438 | Loss: 259.8010 | Time: 2.26s | ⏳ Est. time left: 495.5s
# 🧱 Processando batch 221/438
# 📦 Epoch 6, Batch 220/438 | Loss: 259.9277 | Time: 2.33s | ⏳ Est. time left: 508.9s
# 🧱 Processando batch 222/438
# 📦 Epoch 6, Batch 221/438 | Loss: 271.3813 | Time: 2.40s | ⏳ Est. time left: 520.7s
# 🧱 Processando batch 223/438
# 📦 Epoch 6, Batch 222/438 | Loss: 256.1636 | Time: 2.33s | ⏳ Est. time left: 503.4s
# 🧱 Processando batch 224/438
# 📦 Epoch 6, Batch 223/438 | Loss: 262.3959 | Time: 2.30s | ⏳ Est. time left: 494.8s
# 🧱 Processando batch 225/438
# 📦 Epoch 6, Batch 224/438 | Loss: 236.3197 | Time: 2.32s | ⏳ Est. time left: 495.8s
# 🧱 Processando batch 226/438
# 📦 Epoch 6, Batch 225/438 | Loss: 261.9155 | Time: 2.36s | ⏳ Est. time left: 501.9s
# 🧱 Processando batch 227/438
# 📦 Epoch 6, Batch 226/438 | Loss: 276.3867 | Time: 1.98s | ⏳ Est. time left: 419.6s
# 🧱 Processando batch 228/438
# 📦 Epoch 6, Batch 227/438 | Loss: 267.0059 | Time: 2.32s | ⏳ Est. time left: 490.3s
# 🧱 Processando batch 229/438
# 📦 Epoch 6, Batch 228/438 | Loss: 306.4266 | Time: 2.40s | ⏳ Est. time left: 504.1s
# 🧱 Processando batch 230/438
# 📦 Epoch 6, Batch 229/438 | Loss: 262.3615 | Time: 2.30s | ⏳ Est. time left: 479.9s
# 🧱 Processando batch 231/438
# 📦 Epoch 6, Batch 230/438 | Loss: 250.5154 | Time: 2.32s | ⏳ Est. time left: 482.2s
# 🧱 Processando batch 232/438
# 📦 Epoch 6, Batch 231/438 | Loss: 217.0961 | Time: 2.23s | ⏳ Est. time left: 462.2s
# 🧱 Processando batch 233/438
# 📦 Epoch 6, Batch 232/438 | Loss: 227.9728 | Time: 2.33s | ⏳ Est. time left: 479.3s
# 🧱 Processando batch 234/438
# 📦 Epoch 6, Batch 233/438 | Loss: 258.3710 | Time: 2.04s | ⏳ Est. time left: 417.5s
# 🧱 Processando batch 235/438
# 📦 Epoch 6, Batch 234/438 | Loss: 212.7877 | Time: 2.23s | ⏳ Est. time left: 454.9s
# 🧱 Processando batch 236/438
# 📦 Epoch 6, Batch 235/438 | Loss: 263.0914 | Time: 2.27s | ⏳ Est. time left: 460.8s
# 🧱 Processando batch 237/438
# 📦 Epoch 6, Batch 236/438 | Loss: 270.9114 | Time: 2.27s | ⏳ Est. time left: 458.0s
# 🧱 Processando batch 238/438
# 📦 Epoch 6, Batch 237/438 | Loss: 224.5031 | Time: 2.37s | ⏳ Est. time left: 476.7s
# 🧱 Processando batch 239/438
# 📦 Epoch 6, Batch 238/438 | Loss: 256.3740 | Time: 2.29s | ⏳ Est. time left: 458.9s
# 🧱 Processando batch 240/438
# 📦 Epoch 6, Batch 239/438 | Loss: 267.2920 | Time: 2.26s | ⏳ Est. time left: 448.8s
# 🧱 Processando batch 241/438
# 📦 Epoch 6, Batch 240/438 | Loss: 293.9448 | Time: 2.20s | ⏳ Est. time left: 436.2s
# 🧱 Processando batch 242/438
# 📦 Epoch 6, Batch 241/438 | Loss: 287.2392 | Time: 2.21s | ⏳ Est. time left: 435.4s
# 🧱 Processando batch 243/438
# 📦 Epoch 6, Batch 242/438 | Loss: 243.0957 | Time: 2.21s | ⏳ Est. time left: 432.2s
# 🧱 Processando batch 244/438
# 📦 Epoch 6, Batch 243/438 | Loss: 213.4493 | Time: 2.23s | ⏳ Est. time left: 434.8s
# 🧱 Processando batch 245/438
# 📦 Epoch 6, Batch 244/438 | Loss: 258.2101 | Time: 2.21s | ⏳ Est. time left: 428.3s
# 🧱 Processando batch 246/438
# 📦 Epoch 6, Batch 245/438 | Loss: 216.7301 | Time: 2.21s | ⏳ Est. time left: 426.1s
# 🧱 Processando batch 247/438
# 📦 Epoch 6, Batch 246/438 | Loss: 266.3004 | Time: 2.22s | ⏳ Est. time left: 427.0s
# 🧱 Processando batch 248/438
# 📦 Epoch 6, Batch 247/438 | Loss: 230.6640 | Time: 2.28s | ⏳ Est. time left: 435.6s
# 🧱 Processando batch 249/438
# 📦 Epoch 6, Batch 248/438 | Loss: 299.7871 | Time: 2.26s | ⏳ Est. time left: 428.6s
# 🧱 Processando batch 250/438
# 📦 Epoch 6, Batch 249/438 | Loss: 292.8416 | Time: 2.29s | ⏳ Est. time left: 433.1s
# 🧱 Processando batch 251/438
# 📦 Epoch 6, Batch 250/438 | Loss: 232.3922 | Time: 2.27s | ⏳ Est. time left: 426.9s
# 🧱 Processando batch 252/438
# 📦 Epoch 6, Batch 251/438 | Loss: 274.7174 | Time: 2.30s | ⏳ Est. time left: 429.9s
# 🧱 Processando batch 253/438
# 📦 Epoch 6, Batch 252/438 | Loss: 303.5898 | Time: 2.24s | ⏳ Est. time left: 417.2s
# 🧱 Processando batch 254/438
# 📦 Epoch 6, Batch 253/438 | Loss: 276.6983 | Time: 2.22s | ⏳ Est. time left: 410.5s
# 🧱 Processando batch 255/438
# 📦 Epoch 6, Batch 254/438 | Loss: 256.8065 | Time: 2.22s | ⏳ Est. time left: 408.2s
# 🧱 Processando batch 256/438

# %%
###########################################
# 5. Avaliação
###########################################
def compute_iou(box1, box2):
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    inter_area = max(0, x2 - x1) * max(0, y2 - y1)
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union_area = box1_area + box2_area - inter_area
    return inter_area / union_area if union_area > 0 else 0


def evaluate(model, loader, device, iou_threshold=0.5, confidence_threshold=0.6):
    model.eval()
    total = 0
    correct_weather, correct_scene, correct_time = 0, 0, 0
    total_gt = 0
    correct_category = 0
    detections_count = 0
    with torch.no_grad():
        for images, targets, attrs in loader:
            if not images:
                continue
            images = [img.to(device) for img in images]
            # Predição dos atributos globais
            _, _, w_logits, s_logits, t_logits = model(images)
            w_preds = torch.argmax(w_logits, dim=1).cpu()
            s_preds = torch.argmax(s_logits, dim=1).cpu()
            t_preds = torch.argmax(t_logits, dim=1).cpu()
            w_true = torch.stack([a["weather"] for a in attrs])
            s_true = torch.stack([a["scene"] for a in attrs])
            t_true = torch.stack([a["timeofday"] for a in attrs])
            correct_weather += (w_preds == w_true).sum().item()
            correct_scene += (s_preds == s_true).sum().item()
            correct_time += (t_preds == t_true).sum().item()
            total += len(images)
            # Avaliação de detecções
            detections_batch = model.detection_model(images)
            for i, detection in enumerate(detections_batch):
                gt_boxes = targets[i]["boxes"].cpu().numpy()
                gt_labels = targets[i]["labels"].cpu().numpy()
                total_gt += len(gt_boxes)
                pred_boxes = detection["boxes"].cpu().numpy()
                pred_labels = detection["labels"].cpu().numpy()
                pred_scores = detection["scores"].cpu().numpy()
                keep = pred_scores >= confidence_threshold
                pred_boxes = pred_boxes[keep]
                pred_labels = pred_labels[keep]
                for j, gt_box in enumerate(gt_boxes):
                    best_iou = 0
                    best_idx = -1
                    for k, pred_box in enumerate(pred_boxes):
                        iou = compute_iou(gt_box, pred_box)
                        if iou > best_iou:
                            best_iou = iou
                            best_idx = k
                    if best_iou >= iou_threshold:
                        detections_count += 1
                        if pred_labels[best_idx] == gt_labels[j]:
                            correct_category += 1
    weather_acc = correct_weather / total if total > 0 else 0
    scene_acc = correct_scene / total if total > 0 else 0
    time_acc = correct_time / total if total > 0 else 0
    detection_cat_acc = correct_category / total_gt if total_gt > 0 else 0
    avg_detections = detections_count / total if total > 0 else 0
    print(f"📊 Avaliação em {total} imagens:")
    print(f"🌤️ Acurácia Weather: {weather_acc:.2%}")
    print(f"🌆 Acurácia Scene:   {scene_acc:.2%}")
    print(f"🌙 Acurácia Time:    {time_acc:.2%}")
    print(f"📦 Média de detecções por imagem (matched): {avg_detections:.2f}")
    print(f"🎯 Acurácia de categorias: {detection_cat_acc:.2%}")
    return weather_acc, scene_acc, time_acc, avg_detections, detection_cat_acc


print("Iniciando avaliação...")
evaluate(multi_task_model, loaders["val"], device, iou_threshold=0.5, confidence_threshold=0.6)

# %%
###########################################
# 6. Inferência em múltiplas imagens do conjunto de teste
###########################################
def invert_mapping(mapping):
    return {v: k for k, v in mapping.items()}


def infer_and_annotate_image(image_path, model, device, transform,
                             category_to_label, weather_to_label,
                             scene_to_label, timeofday_to_label,
                             confidence_threshold=0.5):
    inv_category = invert_mapping(category_to_label)
    inv_weather = invert_mapping(weather_to_label)
    inv_scene = invert_mapping(scene_to_label)
    inv_timeofday = invert_mapping(timeofday_to_label)
    orig_image = Image.open(image_path).convert("RGB")
    input_image = transform(orig_image).to(device).unsqueeze(0)
    model.eval()
    with torch.no_grad():
        detections = model.detection_model([input_image.squeeze(0)])
        feats = model.backbone(input_image)
        pooled = model.attr_pool(feats)
        pooled = pooled.view(pooled.size(0), -1)
        weather_logits = model.fc_weather(pooled)
        scene_logits = model.fc_scene(pooled)
        timeofday_logits = model.fc_timeofday(pooled)
        weather_pred = int(torch.argmax(weather_logits, dim=1).item())
        scene_pred = int(torch.argmax(scene_logits, dim=1).item())
        timeofday_pred = int(torch.argmax(timeofday_logits, dim=1).item())
        global_attributes = {
            "weather": inv_weather.get(weather_pred, str(weather_pred)),
            "scene": inv_scene.get(scene_pred, str(scene_pred)),
            "timeofday": inv_timeofday.get(timeofday_pred, str(timeofday_pred))
        }
        detection = detections[0]
        boxes = detection["boxes"].cpu().numpy().tolist()
        labels = detection["labels"].cpu().numpy().tolist()
        scores = detection["scores"].cpu().numpy().tolist()
        detection_list = []
        for bbox, label, score in zip(boxes, labels, scores):
            if score < confidence_threshold:
                continue
            detection_list.append({
                "category": inv_category.get(label, str(label)),
                "score": score,
                "box": bbox
            })
    draw = ImageDraw.Draw(orig_image)
    try:
        font = ImageFont.truetype("arial.ttf", 15)
    except Exception:
        font = ImageFont.load_default()
    for det in detection_list:
        bbox = det["box"]
        text = f"{det['category']}: {det['score']:.2f}"
        draw.rectangle(bbox, outline="red", width=2)
        draw.text((bbox[0], bbox[1] - 10), text, fill="red", font=font)
    attr_text = f"Weather: {global_attributes['weather']}, Scene: {global_attributes['scene']}, Time: {global_attributes['timeofday']}"
    draw.text((10, 10), attr_text, fill="blue", font=font)
    return orig_image, {"global_attributes": global_attributes, "detections": detection_list}


def infer_on_test_folder(test_folder, output_folder, model, device, transform,
                         category_to_label, weather_to_label, scene_to_label, timeofday_to_label,
                         confidence_threshold=0.5):
    os.makedirs(output_folder, exist_ok=True)
    results = {}
    for filename in os.listdir(test_folder):
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(test_folder, filename)
            annotated_img, output = infer_and_annotate_image(image_path, model, device, transform,
                                                             category_to_label, weather_to_label, scene_to_label,
                                                             timeofday_to_label,
                                                             confidence_threshold)
            base_name = os.path.splitext(filename)[0]
            annotated_image_path = os.path.join(output_folder, f"{base_name}_annotated.jpg")
            json_output_path = os.path.join(output_folder, f"{base_name}.json")
            annotated_img.save(annotated_image_path)
            with open(json_output_path, "w") as f:
                json.dump(output, f, indent=2)
            print(f"Processado: {filename}")
            results[filename] = output
    return results


print("Iniciando inferência no conjunto de teste...")
test_folder = "images/test"
output_folder = f"{model_type}_outputs"
inference_results = infer_on_test_folder(test_folder, output_folder, multi_task_model, device, transform,
                                         category_to_label, weather_to_label, scene_to_label, timeofday_to_label,
                                         confidence_threshold=0.5)
print("Inferência concluída. Resultados:")
print(json.dumps(inference_results, indent=2))
